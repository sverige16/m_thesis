# %%
import pandas as pd

# %% [markdown]
# # Prepping Clue_sig by adding MoA in order to extract using MOA

# %%
clue_sig_in_SPECS = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/04_Tomics_Models/init_data_expl/clue_sig_in_SPECS1&2.csv', delimiter = ",")

# %%
clue_sig_in_SPECS.shape
# Out:
# (53975, 41)

# %%
clue_sig_in_SPECS
# Out:
#        Unnamed: 0    pert_id Compound ID   Batch nr  \
# 0               0  A39052811   CBK290537  BJ1898259
# 1               1  A39052811   CBK290537  BJ1898259
# 2               2  A39052811   CBK290537  BJ1898259
# 3               3  A39052811   CBK290537  BJ1898259
# 4               4  A39052811   CBK290537  BJ1898259
# ...           ...        ...         ...        ...
# 53970       53970  A63236097   CBK290667  BJ1898465
# 53971       53971  A63236097   CBK290667  BJ1898465
# 53972       53972  A63236097   CBK290667  BJ1898465
# 53973       53973  A63236097   CBK290667  BJ1898465
# 53974       53974  A63236097   CBK290667  BJ1898465
#
#                               moa bead_batch  nearest_dose  pert_dose  \
# 0      serotonin receptor agonist        b18         10.00  10.000000
# 1      serotonin receptor agonist        b18         10.00  10.000000
# 2      serotonin receptor agonist        b18         10.00  10.000000
# 3      serotonin receptor agonist        b18         10.00  10.000000
# 4      serotonin receptor agonist        b18         10.00  10.000000
# ...                           ...        ...           ...        ...
# 53970                         NaN        b34          0.04   0.041152
# 53971                         NaN        b34          3.33   3.333330
# 53972                         NaN        b34          1.11   1.111110
# 53973                         NaN        b34          0.37   0.370370
# 53974                         NaN        b34          1.11   1.111110
#
#       pert_dose_unit pert_idose  ... cell_iname  det_wells  \
# 0                 uM      10 uM  ...       WI38        D04
# 1                 uM      10 uM  ...       NL20        D04
# 2                 uM      10 uM  ...       A549        D04
# 3                 uM      10 uM  ...      IMR90        D04
# 4                 uM      10 uM  ...       HFL1        D04
# ...              ...        ...  ...        ...        ...
# 53970             uM    0.04 uM  ...     HCT116        C18
# 53971             uM    3.33 uM  ...     MCF10A        C14
# 53972             uM    1.11 uM  ...     MCF10A        C15
# 53973             uM    0.37 uM  ...     HCT116        C16
# 53974             uM    1.11 uM  ...     MCF10A        C15
#
#                                               det_plates  \
# 0      LUNG001_WI38_24H_X1_B18|LUNG001_WI38_24H_X2_B1...
# 1        LUNG001_NL20_24H_X1_B18|LUNG001_NL20_24H_X3_B18
# 2        LUNG001_A549_24H_X1_B18|LUNG001_A549_24H_X2_B18
# 3      LUNG001_IMR90_24H_X1_B18|LUNG001_IMR90_24H_X2_...
# 4      LUNG001_HFL1_24H_X1_B18|LUNG001_HFL1_24H_X2_B1...
# ...                                                  ...
# 53970  ISO002_HCT116.TP53.HR_24H_X1_B34|ISO002_HCT116...
# 53971  ISO002_MCF10A.BRCA1.HD_24H_X1_B34|ISO002_MCF10...
# 53972            ISO002_MCF10A.TP53.M.EGFR.HL_24H_X3_B34
# 53973  ISO002_HCT116.TP53.HR_24H_X1_B34|ISO002_HCT116...
# 53974  ISO002_MCF10A.TP53.M_24H_X1_B34|ISO002_MCF10A....
#
#                                               distil_ids build_name  \
# 0      LUNG001_WI38_24H_X1_B18:D04|LUNG001_WI38_24H_X...        NaN
# 1      LUNG001_NL20_24H_X1_B18:D04|LUNG001_NL20_24H_X...        NaN
# 2      LUNG001_A549_24H_X1_B18:D04|LUNG001_A549_24H_X...        NaN
# 3      LUNG001_IMR90_24H_X1_B18:D04|LUNG001_IMR90_24H...        NaN
# 4      LUNG001_HFL1_24H_X1_B18:D04|LUNG001_HFL1_24H_X...        NaN
# ...                                                  ...        ...
# 53970  ISO002_HCT116.TP53.HR_24H_X1_B34:C18|ISO002_HC...        NaN
# 53971  ISO002_MCF10A.BRCA1.HD_24H_X1_B34:C14|ISO002_M...        NaN
# 53972        ISO002_MCF10A.TP53.M.EGFR.HL_24H_X3_B34:C15        NaN
# 53973  ISO002_HCT116.TP53.HR_24H_X1_B34:C16|ISO002_HC...        NaN
# 53974  ISO002_MCF10A.TP53.M_24H_X1_B34:C15|ISO002_MCF...        NaN
#
#        project_code      cmap_name  is_exemplar_sig  is_ncs_sig  is_null_sig
# 0              LUNG      mosapride              0.0         0.0          0.0
# 1              LUNG      mosapride              0.0         0.0          0.0
# 2              LUNG      mosapride              0.0         1.0          0.0
# 3              LUNG      mosapride              0.0         0.0          0.0
# 4              LUNG      mosapride              0.0         0.0          0.0
# ...             ...            ...              ...         ...          ...
# 53970           ISO  BRD-A63236097              0.0         1.0          0.0
# 53971           ISO  BRD-A63236097              0.0         1.0          0.0
# 53972           ISO  BRD-A63236097              0.0         0.0          0.0
# 53973           ISO  BRD-A63236097              0.0         1.0          0.0
# 53974           ISO  BRD-A63236097              0.0         1.0          0.0
#
# [53975 rows x 41 columns]

# %%
clue_sig_in_SPECS.columns
# Out:
# Index(['Unnamed: 0', 'pert_id', 'Compound ID', 'Batch nr', 'moa', 'bead_batch',
#        'nearest_dose', 'pert_dose', 'pert_dose_unit', 'pert_idose',
#        'pert_itime', 'pert_time', 'pert_time_unit', 'cell_mfc_name',
#        'pert_mfc_id', 'nsample', 'cc_q75', 'ss_ngene', 'tas',
#        'pct_self_rank_q25', 'wt', 'median_recall_rank_spearman',
#        'median_recall_rank_wtcs_50', 'median_recall_score_spearman',
#        'median_recall_score_wtcs_50', 'batch_effect_tstat',
#        'batch_effect_tstat_pct', 'is_hiq', 'qc_pass', 'sig_id', 'pert_type',
#        'cell_iname', 'det_wells', 'det_plates', 'distil_ids', 'build_name',
#        'project_code', 'cmap_name', 'is_exemplar_sig', 'is_ncs_sig',
#        'is_null_sig'],
#       dtype='object')

# %%
moa_names = ["cyclooxygenase inhibitor", "dopamine receptor antagonist","adrenergic receptor antagonist", "phosphodiesterase inhibitor",  "HDAC inhibitor", 
             "histamine receptor antagonist","EGFR inhibitor", "adrenergic receptor agonist", "PARP inhibitor",  "topoisomerase inhibitor"]

# %% [markdown]
# # Pseudo Code to Extract Relevant Transcriptomic Profiles
# 1. Extract the Column Ids of all of the transcriptomic profiles from all of the MoAs that we want to include.
# Concatenate them to one large pandas dataframe.
# 2. Extract row columns of landmark genes only.
# 3. Use CMapPy to extract relevant genes and profiles from GCTX.

# %% [markdown]
# ## Extract the Column Ids of all of the transcriptomic profiles from all of the MoAs that we want to include. Concatenate them to one large pandas dataframe.

# %%
'''all_ids = pd.DataFrame()
for i in moa_names:
    # get all samples (across all cell types, doses, and other treatment conditions) that were treated with vorinostat
    ids = clue_sig_in_SPECS["sig_id"][clue_sig_in_SPECS["moa"] == i]
    print(f' number of samples treated with {i}: {ids.shape[0]}')
    all_ids = pd.concat([all_ids, ids])
# how many samples are there in this data set?
print(f'number of samples with these moa_names: {all_ids.shape[0]} ')
'''
# Out:
# 'all_ids = pd.DataFrame()\nfor i in moa_names:\n    # get all samples (across all cell types, doses, and other treatment conditions) that were treated with vorinostat\n    ids = clue_sig_in_SPECS["sig_id"][clue_sig_in_SPECS["moa"] == i]\n    print(f\' number of samples treated with {i}: {ids.shape[0]}\')\n    all_ids = pd.concat([all_ids, ids])\n# how many samples are there in this data set?\nprint(f\'number of samples with these moa_names: {all_ids.shape[0]} \')\n'

# %%
all_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-231-66fe875f24ba> in <module>
# ----> 1 all_ids
#
# NameError: name 'all_ids' is not defined

# %%
ids = clue_sig_in_SPECS["sig_id"][clue_sig_in_SPECS["moa"] == "cyclooxygenase inhibitor"]

# %%
ids
# Out:
# 1291                        LRS001_PHH.MGH_24H:D11
# 1292                        LRS001_PHH.MGH_24H:D12
# 1293                        LRS001_PHH.MGH_24H:D10
# 1294                           CPC006_RMUGS_6H:H02
# 1295                           CPC006_SW620_6H:H02
#                            ...
# 35308     CPC004_MCF7_6H:BRD-K68558722-001-03-2:10
# 35309    CPC004_HEPG2_6H:BRD-K68558722-001-03-2:10
# 35310     CPC015_SKB_24H:BRD-K68558722-001-03-2:10
# 35311                          CPC004_VCAP_24H:H09
# 38347                         LIVB001_HUH7_72H:L05
# Name: sig_id, Length: 1184, dtype: object

# %% [markdown]
# Looks good compared to other function I created to check transcriptomes.

# %% [markdown]
# ## Extract row columns of landmark genes only.

# %%
# identifying rows with only landmark genes
clue_gene = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/04_Tomics_Models/init_data_expl/clue_geneinfo_beta.txt', delimiter = "\t")
clue_gene.columns
# again, note that because gene_info dtypes are str, you need to find ids equal to "1" not 1 
#landmark_gene_row_ids = gene_info["pr_gene_id"][gene_info["pr_is_lm"] == "1"]
# Out:
# Index(['gene_id', 'gene_symbol', 'ensembl_id', 'gene_title', 'gene_type',
#        'src', 'feature_space'],
#       dtype='object')

# %%
clue_gene
# Out:
#          gene_id gene_symbol       ensembl_id  \
# 0            750    GAS8-AS1  ENSG00000221819
# 1           6315     ATXN8OS              NaN
# 2           7503        XIST  ENSG00000229807
# 3           8552        INE1  ENSG00000224975
# 4           9834      FAM30A  ENSG00000226777
# ...          ...         ...              ...
# 12323  100287932      TIMM23  ENSG00000265354
# 12324  100289678      ZNF783  ENSG00000204946
# 12325  100507436        MICA  ENSG00000204520
# 12326       9142     TMEM257  ENSG00000221870
# 12327      26148    C10orf12  ENSG00000155640
#
#                                            gene_title       gene_type   src  \
# 0                                GAS8 antisense RNA 1           ncRNA  NCBI
# 1                        ATXN8 opposite strand lncRNA           ncRNA  NCBI
# 2                      X inactive specific transcript           ncRNA  NCBI
# 3                               inactivation escape 1           ncRNA  NCBI
# 4         family with sequence similarity 30 member A           ncRNA  NCBI
# ...                                               ...             ...   ...
# 12323  translocase of inner mitochondrial membrane 23  protein-coding  NCBI
# 12324                   zinc finger family member 783  protein-coding  NCBI
# 12325      MHC class I polypeptide-related sequence A  protein-coding  NCBI
# 12326                       transmembrane protein 257  protein-coding  NCBI
# 12327             chromosome 10 open reading frame 12  protein-coding  NCBI
#
#        feature_space
# 0           inferred
# 1           inferred
# 2           inferred
# 3           inferred
# 4           inferred
# ...              ...
# 12323  best inferred
# 12324  best inferred
# 12325  best inferred
# 12326  best inferred
# 12327  best inferred
#
# [12328 rows x 7 columns]

# %%
clue_gene = clue_gene.astype({"gene_id": str})

# %%
clue_gene["gene_id"] = clue_gene["gene_id"].astype(str)

# %%
clue_gene["gene_id"].dtypes
# Out:
# dtype('O')

# %% [markdown]
# pandas string

# %%
landmark_gene_row_ids = clue_gene["gene_id"][clue_gene["feature_space"] == "landmark"]

# %%
landmark_gene_row_ids
# Out:
# 2154        16
# 2155        23
# 2156        25
# 2157        30
# 2158        39
#          ...
# 3127    200081
# 3128    200734
# 3129    256364
# 3130    375346
# 3131    388650
# Name: gene_id, Length: 978, dtype: object

# %% [markdown]
# Looks correct compared to gene_expression_data investigation

# %% [markdown]
# ## Use CMapPy to extract relevant genes and profiles from GCTX.

# %%
# parse columns
from cmapPy.pandasGEXpress.parse import parse
'''
Selected_10_moas_gctoo = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx",
                              rid = landmark_gene_row_ids)'''
# Out:
# '\nSelected_10_moas_gctoo = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx",\n                              rid = landmark_gene_row_ids)'

# %%
my_col_metadata = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx", col_meta_only=True)
my_col_metadata
# Out:
# Empty DataFrame
# Columns: []
# Index: [ABY001_A375_XH:BRD-A61304759:0.625:24, ABY001_A375_XH:BRD-A61304759:0.625:3, ABY001_A375_XH:BRD-A61304759:10:24, ABY001_A375_XH:BRD-A61304759:10:3, ABY001_A375_XH:BRD-A61304759:2.5:24, ABY001_A375_XH:BRD-A61304759:2.5:3, ABY001_A375_XH:BRD-A90490067:0.625:24, ABY001_A375_XH:BRD-A90490067:0.625:3, ABY001_A375_XH:BRD-A90490067:10:24, ABY001_A375_XH:BRD-A90490067:10:3, ABY001_A375_XH:BRD-A90490067:2.5:24, ABY001_A375_XH:BRD-A90490067:2.5:3, ABY001_A375_XH:BRD-K19687926:0.625:24, ABY001_A375_XH:BRD-K19687926:0.
687926:0.625:3, ABY001_A549_XH:BRD-K19687926:10:24, ABY001_A549_XH:BRD-K19687926:10:3, ABY001_A549_XH:BRD-K19687926:2.5:24, ABY001_A549_XH:BRD-K19687926:2.5:3, ABY001_A549_XH:BRD-K21680192:0.625:24, ABY001_A549_XH:BRD-K21680192:0.625:3, ABY001_A549_XH:BRD-K21680192:10:24, ABY001_A549_XH:BRD-K21680192:10:3, ABY001_A549_XH:BRD-K21680192:2.5:24, ABY001_A549_XH:BRD-K21680192:2.5:3, ABY001_A549_XH:BRD-K66175015:0.625:24, ABY001_A549_XH:BRD-K66175015:0.625:3, ABY001_A549_XH:BRD-K66175015:10:24, ABY001_A549_XH:BRD-K66175015:10:3, ABY001_A549_XH:BRD-K66175015:2.5:24, ABY001_A549_XH:BRD-K66175015:2.5:3, ABY001_A549_XH:BRD-K70401845:0.625:24, ABY001_A549_XH:BRD-K70401845:0.625:3, ABY001_A549_XH:BRD-K70401845:10:24, ABY001_A549_XH:BRD-K70401845:10:3, ABY001_A549_XH:BRD-K70401845:2.5:24, ABY001_A549_XH:BRD-K70401845:2.5:3, ABY001_A549_XH:BRD-K70511574:0.625:24, ABY001_A549_XH:BRD-K70511574:0.625:3, ABY001_A549_XH:BRD-K70511574:10:24, ABY001_A549_XH:BRD-K70511574:10:3, ...]
#
# [720216 rows x 0 columns]

# %% [markdown]
# ## Example from CMAP tutorial: Pseudocode
# 1. extract from metadata which samples that you want to have and extract samples
# 2. copy the metadata from those samples
# 3. set it as the column or row metadata
# 4. From that metadata, subset if need be

# %% [markdown]
# ### 1. extract from metadata which samples that you want to have and extract samples

# %%
# get all samples (across all cell types, doses, and other treatment conditions) that were treated with vorinostat
vorinostat_ids = clue_sig_in_SPECS["sig_id"][clue_sig_in_SPECS["cmap_name"] == "vorinostat"]
# how many samples are there in this data set?
print("number of samples treated with vorinostat:")
len(vorinostat_ids)
# Out:
# number of samples treated with vorinostat:
# 2229

# %%
vorinostat_ids
# Out:
# 15283                ABY001_A549_XH:BRD-K81418486:10:3
# 15284                  LTC002_HME1_3H:BRD-K81418486:10
# 15285              LTC008_MDAMB231_3H:BRD-K81418486:10
# 15286        RAD001_MCF7_24H:BRD-K81418486-001-18-6:10
# 15287    RAD001_MCF7_24H:BRD-K81418486-001-18-6:3.3333
#                              ...
# 17507                             LJP009_SKL.C_24H:A03
# 17508                            LJP008_HEK293_24H:G10
# 17509                              LJP008_A375_24H:G10
# 17510                            LJP008_SHSY5Y_24H:G10
# 17511                           LJP008_HUVEC.A_24H:G09
# Name: sig_id, Length: 2229, dtype: object

# %%
vorinostat_only_gctoo = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx", cid= vorinostat_ids)

# %%
vorinostat_only_gctoo.data_df.shape
# Out:
# (12328, 2229)

# %%
vorinostat_only_gctoo.col_metadata_df[0:5]
# Out:
# Empty DataFrame
# Columns: []
# Index: [ABY001_A375_XH:BRD-K81418486:0.625:24, ABY001_A375_XH:BRD-K81418486:0.625:3, ABY001_A375_XH:BRD-K81418486:10:24, ABY001_A375_XH:BRD-K81418486:10:3, ABY001_A375_XH:BRD-K81418486:2.5:24]

# %% [markdown]
# ### 2. copy the metadata from those samples

# %%
# first, we need to subset all the metadata information from our larger metadata DataFrame
# col
vorinostat_sig_id_info =  clue_sig_in_SPECS[clue_sig_in_SPECS["cmap_name"] == "vorinostat"]

# %%
# row 
vorinostat_gene_id_info =  clue_gene

# %%
# let's look at a couple rows! 
vorinostat_sig_id_info[0:5]
# Out:
#        Unnamed: 0    pert_id Compound ID   Batch nr             moa  \
# 15283       15283  K81418486   CBK201016  BJ1898152  HDAC inhibitor
# 15284       15284  K81418486   CBK201016  BJ1898152  HDAC inhibitor
# 15285       15285  K81418486   CBK201016  BJ1898152  HDAC inhibitor
# 15286       15286  K81418486   CBK201016  BJ1898152  HDAC inhibitor
# 15287       15287  K81418486   CBK201016  BJ1898152  HDAC inhibitor
#
#       bead_batch  nearest_dose  pert_dose pert_dose_unit pert_idose  ...  \
# 15283        b15         10.00    10.0000             uM      10 uM  ...
# 15284        b18         10.00    10.0000             uM      10 uM  ...
# 15285        b18         10.00    10.0000             uM      10 uM  ...
# 15286       f1b5         10.00    10.0000             uM      10 uM  ...
# 15287       f1b5          3.33     3.3333             uM    3.33 uM  ...
#
#       cell_iname    det_wells                           det_plates  \
# 15283       A549  L04|L08|L12                ABY001_A549_XH_X1_B15
# 15284       HME1          F19                LTC002_HME1_3H_X1_B18
# 15285   MDAMB231          O23            LTC008_MDAMB231_3H_X1_B18
# 15286       MCF7          M03  RAD001_MCF7_24H_X3_F1B5_DUO52HI53LO
# 15287       MCF7          M04  RAD001_MCF7_24H_X3_F1B5_DUO52HI53LO
#
#                                               distil_ids build_name  \
# 15283  ABY001_A549_XH_X1_B15:L04|ABY001_A549_XH_X1_B1...        NaN
# 15284                          LTC002_HME1_3H_X1_B18:F19        NaN
# 15285                      LTC008_MDAMB231_3H_X1_B18:O23        NaN
# 15286            RAD001_MCF7_24H_X3_F1B5_DUO52HI53LO:M03        NaN
# 15287            RAD001_MCF7_24H_X3_F1B5_DUO52HI53LO:M04        NaN
#
#        project_code   cmap_name  is_exemplar_sig  is_ncs_sig  is_null_sig
# 15283           ABY  vorinostat              0.0         1.0          0.0
# 15284           LTC  vorinostat              0.0         0.0          0.0
# 15285           LTC  vorinostat              0.0         0.0          0.0
# 15286           RAD  vorinostat              0.0         0.0          0.0
# 15287           RAD  vorinostat              0.0         0.0          0.0
#
# [5 rows x 41 columns]

# %%
vorinostat_gene_id_info[0:5]
# Out:
#   gene_id gene_symbol       ensembl_id  \
# 0     750    GAS8-AS1  ENSG00000221819
# 1    6315     ATXN8OS              NaN
# 2    7503        XIST  ENSG00000229807
# 3    8552        INE1  ENSG00000224975
# 4    9834      FAM30A  ENSG00000226777
#
#                                     gene_title gene_type   src feature_space
# 0                         GAS8 antisense RNA 1     ncRNA  NCBI      inferred
# 1                 ATXN8 opposite strand lncRNA     ncRNA  NCBI      inferred
# 2               X inactive specific transcript     ncRNA  NCBI      inferred
# 3                        inactivation escape 1     ncRNA  NCBI      inferred
# 4  family with sequence similarity 30 member A     ncRNA  NCBI      inferred

# %%
vorinostat_sig_id_info.set_index("sig_id", inplace=True)
# now the data frame is indexed by sig_ids consistent with those of the data_df:
vorinostat_sig_id_info.index
# Out:
# Index(['ABY001_A549_XH:BRD-K81418486:10:3', 'LTC002_HME1_3H:BRD-K81418486:10',
#        'LTC008_MDAMB231_3H:BRD-K81418486:10',
#        'RAD001_MCF7_24H:BRD-K81418486-001-18-6:10',
#        'RAD001_MCF7_24H:BRD-K81418486-001-18-6:3.3333',
#        'RAD001_PC3_6H:BRD-K81418486-001-18-6:0.1235',
#        'RAD001_MCF7_6H:BRD-K81418486-001-18-6:0.0015',
#        'NMH001_FIBRNPC_6H:BRD-K81418486-001-22-8:10',
#        'HOG003_A549_24H:BRD-K81418486-001-32-7:1.11', 'POL001_PC3_24H:O01',
#        ...
#        'LJP008_JURKAT_24H:A03', 'LJP008_NEU_24H:A03', 'LJP008_PC3_24H:G08',
#        'LJP008_HA1E_24H:A03', 'LJP008_MCF7_24H:G12', 'LJP009_SKL.C_24H:A03',
#        'LJP008_HEK293_24H:G10', 'LJP008_A375_24H:G10', 'LJP008_SHSY5Y_24H:G10',
#        'LJP008_HUVEC.A_24H:G09'],
#       dtype='object', name='sig_id', length=2229)

# %%
vorinostat_gene_id_info.set_index("gene_id", inplace=True)
# now the data frame is indexed by sig_ids consistent with those of the data_df:
vorinostat_gene_id_info.index
# Out:
# Index(['750', '6315', '7503', '8552', '9834', '10141', '10255', '10281',
#        '23434', '23591',
#        ...
#        '729230', '729515', '100129250', '100131755', '100132406', '100287932',
#        '100289678', '100507436', '9142', '26148'],
#       dtype='object', name='gene_id', length=12328)

# %% [markdown]
# ### 3. Set it as the column or row metadata

# %%
vorinostat_only_gctoo.data_df.shape
# Out:
# (12328, 2229)

# %%
# set the relevant annotations as a col_metadata_df: 
vorinostat_only_gctoo.col_metadata_df = vorinostat_sig_id_info

# %%
vorinostat_only_gctoo.col_metadata_df[0:5]
# Out:
#                                        Unnamed: 0    pert_id Compound ID  \
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24       15605  K81418486   CBK201016
# ABY001_A375_XH:BRD-K81418486:0.625:3        15463  K81418486   CBK201016
# ABY001_A375_XH:BRD-K81418486:10:24          15386  K81418486   CBK201016
# ABY001_A375_XH:BRD-K81418486:10:3           15434  K81418486   CBK201016
# ABY001_A375_XH:BRD-K81418486:2.5:24         15753  K81418486   CBK201016
#
#                                         Batch nr             moa bead_batch  \
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24  BJ1898152  HDAC inhibitor        b15
# ABY001_A375_XH:BRD-K81418486:0.625:3   BJ1898152  HDAC inhibitor        b15
# ABY001_A375_XH:BRD-K81418486:10:24     BJ1898152  HDAC inhibitor        b15
# ABY001_A375_XH:BRD-K81418486:10:3      BJ1898152  HDAC inhibitor        b15
# ABY001_A375_XH:BRD-K81418486:2.5:24    BJ1898152  HDAC inhibitor        b15
#
#                                        nearest_dose  pert_dose pert_dose_unit  \
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24          0.0
# ABY001_A375_XH:BRD-K81418486:0.625:3           0.0
# ABY001_A375_XH:BRD-K81418486:10:24             0.0
# ABY001_A375_XH:BRD-K81418486:10:3              0.0
# ABY001_A375_XH:BRD-K81418486:2.5:24            0.0
#
# [5 rows x 40 columns]

# %%
# set the relevant annotations as a col_metadata_df: 
vorinostat_only_gctoo.row_metadata_df = vorinostat_gene_id_info

# %%
vorinostat_only_gctoo.row_metadata_df[0:100]
# Out:
#       gene_symbol       ensembl_id                                gene_title  \
# rid
# 10           NAT2  ENSG00000156006                     N-acetyltransferase 2
# 100           ADA  ENSG00000196839                       adenosine deaminase
# 1000         CDH2  ENSG00000170558                                cadherin 2
# 10000        AKT3  ENSG00000117020             AKT serine/threonine kinase 3
# 10001        MED6  ENSG00000133997                mediator complex subunit 6
# ...           ...              ...                                       ...
# 10083       USH1C  ENSG00000006611   USH1 protein network component harmonin
# 10084       PQBP1  ENSG00000102103           polyglutamine binding protein 1
# 10085       EDIL3  ENSG00000164176  EGF like repeats and discoidin domains 3
# 10086       HHLA1  ENSG00000132297                  HERV-H LTR-associating 1
# 10087    COL4A3BP  ENSG00000113163  collagen type IV alpha 3 binding protein
#
#             gene_type   src  feature_space
# rid
# 10     protein-coding  NCBI       inferred
# 100    protein-coding  NCBI  best inferred
# 1000   protein-coding  NCBI  best inferred
# 10000  protein-coding  NCBI  best inferred
# 10001  protein-coding  NCBI  best inferred
# ...               ...   ...            ...
# 10083  protein-coding  NCBI  best inferred
# 10084  protein-coding  NCBI  best inferred
# 10085  protein-coding  NCBI  best inferred
# 10086  protein-coding  NCBI       inferred
# 10087  protein-coding  NCBI  best inferred
#
# [100 rows x 6 columns]

# %% [markdown]
# ### 4. From that Metadata, subset if need be

# %%
vorinostat_only_gctoo.col_metadata_df["cell_iname"].unique()
# Out:
# array(['A375', 'A549', 'H1975', 'HEPG2', 'HT29', 'NCIH1975', 'NCIH2073',
#        'NCIH508', 'NCIH596', 'PC3', 'SKBR3', 'SUDHL4', 'MCF7', '22RV1',
#        'A204', 'AGS', 'BC3C', 'BEN', 'BICR6', 'BT474', 'CAL29', 'CJM',
#        'COV434', 'ES2', 'G401', 'GI1', 'GP2D', 'HCC1588', 'HCC95',
#        'HEC108', 'HEC151', 'HEC1A', 'HEC251', 'HEC265', 'IGR37', 'IM95',
#        'JHH5', 'JHH7', 'LNCAP', 'MDAMB468', 'MELHO', 'MKN45', 'NCIH1437',
#        'NCIH1573', 'NCIH2110', 'NCIH2172', 'NCIH838', 'NCIH841', 'OAW28',
#        'OC316', 'OVK18', 'OVTOKO', 'RCC10RGB', 'SH4', 'SKES1', 'SKMEL3',
#        'SNU407', 'T47D', 'TC32', 'TOV112D', 'U251MG', 'YAPC', 'YH13',
#        'ZR751', 'U2OS', 'WA09', 'XC.500', 'XC.L10', 'XC.P026', 'XC.P031',
#        'XC.P033', 'XC.P091', 'XC.P092', 'XC.P901', 'XC.P904', 'XC.P905',
#        'XC.P906', 'XC.P907', 'XC.P908', 'XC.P909', 'XC.P910', 'XC.P911',
#        'XC.P912', 'XC.P914', 'XC.P915', 'XC.P922', 'XC.P930', 'XC.P931',
#        'XC.P932', 'XC.P933', 'XC.P934', 'XC.P935', 'XC.P936', 'HEK293T',
#        'NPC', 'HIMG001', 'HIMG002', 'HA1E', 'HCC515', 'VCAP', 'A673',
#        'CL34', 'CORL23', 'COV644', 'DV90', 'EFO27', 'H1299', 'HCC15',
#        'HCT116', 'HT115', 'JHUEM2', 'LOVO', 'MDST8', 'NCIH1694',
#        'NCIH1836', 'NOMO1', 'OV7', 'PL21', 'RKO', 'RMGI', 'RMUGS',
#        'SKLU1', 'SKM1', 'SKMEL1', 'SKMEL28', 'SNGM', 'SNU1040', 'SNUC4',
#        'SNUC5', 'SW480', 'SW620', 'SW948', 'T3M10', 'THP1', 'TYKNU',
#        'U937', 'WSUDLCL2', 'ASC', 'NEU', 'PHH', 'SKB', 'HUH7', 'C42',
#        'DU145', 'BJAB', 'HBL1', 'K562', 'KMS34', 'MINO', 'NALM6',
#        'OCILY10', 'OCILY19', 'OCILY3', 'SKMEL5', 'TMD8', 'MCF10A',
#        'HUES3', 'SKL', 'CD34', 'HEK293', 'HELA', 'HME1', 'HUVEC',
#        'JURKAT', 'MDAMB231', 'SHSY5Y', 'SKNSH', 'AG06263_2', 'AG06840_A',
#        'AG078N1_1', 'ND34732_7'], dtype=object)

# %%
vorinostat_only_gctoo.row_metadata_df["feature_space"].unique()
# Out:
# array(['inferred', 'best inferred', 'landmark'], dtype=object)

# %% [markdown]
# ### Do it for A549

# %%
import cmapPy.pandasGEXpress.subset_gctoo as sg

# first, get the cid values we want to keep 
vorinostat_A549_ids = vorinostat_only_gctoo.col_metadata_df.index[vorinostat_only_gctoo.col_metadata_df["cell_iname"] == "A549"]


type(list(vorinostat_A549_ids))
vorinostat_A549_ids = list(vorinostat_A549_ids)

# subset GCToo instance to only include these values 
vorinostat_A549_gctoo = sg.subset_gctoo(vorinostat_only_gctoo, cid= vorinostat_A549_ids)

# Now, our samples only correspond to one cell type: A375
vorinostat_A549_gctoo.col_metadata_df["cell_iname"].unique()
# Out:
# array(['A549'], dtype=object)

# %%
vorinostat_A549_gctoo.data_df.shape
# Out:
# (12328, 205)

# %% [markdown]
# ### Do it for a375

# %%
import cmapPy.pandasGEXpress.subset_gctoo as sg

# first, get the cid values we want to keep 
vorinostat_a375_ids = vorinostat_only_gctoo.col_metadata_df.index[vorinostat_only_gctoo.col_metadata_df["cell_iname"] == "A375"]

type(list(vorinostat_a375_ids))
vorinostat_a375_ids = list(vorinostat_a375_ids)

# subset GCToo instance to only include these values 
vorinostat_a375_gctoo = sg.subset_gctoo(vorinostat_only_gctoo, cid=vorinostat_a375_ids)

# Now, our samples only correspond to one cell type: A375
vorinostat_a375_gctoo.col_metadata_df["cell_iname"].unique()
# Out:
# array(['A375'], dtype=object)

# %%
vorinostat_a375_gctoo.data_df.shape
# Out:
# (12328, 117)

# %%
vorinostat_a375_gctoo.col_metadata_df
# Out:
#                                        Unnamed: 0    pert_id Compound ID  \
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24              0.0         1.0
# ABY001_A375_XH:BRD-K81418486:0.625:3               0.0         1.0
# ABY001_A375_XH:BRD-K81418486:10:24                 0.0         1.0
# ABY001_A375_XH:BRD-K81418486:10:3                  0.0         1.0
# ABY001_A375_XH:BRD-K81418486:2.5:24                0.0         1.0
# ...                                                ...         ...
# LPROT002_A375_6H:BRD-K81418486:1                   0.0         1.0
# LPROT003_A375_6H:BRD-K81418486:1                   0.0         1.0
# PCL001_A375_24H:BRD-K81418486:10                   0.0         1.0
# PRISM001_A375_24H:BRD-K81418486:10                 0.0         0.0
# PRISM001_A375_6H:BRD-K81418486:10                  0.0         0.0
#
#                                        is_null_sig
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24          0.0
# ABY001_A375_XH:BRD-K81418486:0.625:3           0.0
# ABY001_A375_XH:BRD-K81418486:10:24             0.0
# ABY001_A375_XH:BRD-K81418486:10:3              0.0
# ABY001_A375_XH:BRD-K81418486:2.5:24            0.0
# ...                                            ...
# LPROT002_A375_6H:BRD-K81418486:1               0.0
# LPROT003_A375_6H:BRD-K81418486:1               0.0
# PCL001_A375_24H:BRD-K81418486:10               0.0
# PRISM001_A375_24H:BRD-K81418486:10             0.0
# PRISM001_A375_6H:BRD-K81418486:10              0.0
#
# [117 rows x 40 columns]

# %%
bro = vorinostat_sig_id_info[["moa", "cell_iname"]]
#vorinostat_a375_gctoo.col_metadata_df

col_metadata_test_info= bro.iloc[0]

#col_metadata_test_info.set_index("sig_id", inplace=True)
# now the data frame is indexed by sig_ids consistent with those of the data_df:
col_metadata_test_info.index
# Out:
# Index(['moa', 'cell_iname'], dtype='object')

# %%
vorinostat_A549_gctoo.row_metadata_df
# Out:
#       gene_symbol       ensembl_id  \
# rid
# 10           NAT2  ENSG00000156006
# 100           ADA  ENSG00000196839
# 1000         CDH2  ENSG00000170558
# 10000        AKT3  ENSG00000117020
# 10001        MED6  ENSG00000133997
# ...           ...              ...
# 9990      SLC12A6  ENSG00000140199
# 9991        PTBP3  ENSG00000119314
# 9992        KCNE2  ENSG00000159197
# 9993        DGCR2  ENSG00000070413
# 9997         SCO2  ENSG00000130489
#
#                                               gene_title       gene_type  \
# rid
# 10                                 N-acetyltransferase 2  protein-coding
# 100                                  adenosine deaminase  protein-coding
# 1000                                          cadherin 2  protein-coding
# 10000                      AKT serine/threonine kinase 3  protein-coding
# 10001                         mediator complex subunit 6  protein-coding
# ...                                                  ...             ...
# 9990                   solute carrier family 12 member 6  protein-coding
# 9991              polypyrimidine tract binding protein 3  protein-coding
# 9992   potassium voltage-gated channel subfamily E re...  protein-coding
# 9993            DiGeorge syndrome critical region gene 2  protein-coding
# 9997         SCO cytochrome c oxidase assembly protein 2  protein-coding
#
#         src  feature_space
# rid
# 10     NCBI       inferred
# 100    NCBI  best inferred
# 1000   NCBI  best inferred
# 10000  NCBI  best inferred
# 10001  NCBI  best inferred
# ...     ...            ...
# 9990   NCBI  best inferred
# 9991   NCBI  best inferred
# 9992   NCBI       inferred
# 9993   NCBI  best inferred
# 9997   NCBI  best inferred
#
# [12328 rows x 6 columns]

# %% [markdown]
# ### Getting the Mean for Each Cell Line

# %%
mean_a375 = vorinostat_a375_gctoo.data_df.mean(axis = 1)
mean_a375.row_metadata_df = vorinostat_gene_id_info
mean_a375.data_df = mean_a375
mean_A549 = vorinostat_A549_gctoo.data_df.mean(axis = 1)
mean_A549.row_metadata_df = vorinostat_gene_id_info
mean_A549.data_df = mean_A549

# %%
mean_a375
# Out:
# rid
# 10       0.649421
# 100      1.050561
# 1000    -0.723552
# 10000   -0.625600
# 10001   -0.231826
#            ...
# 9990     0.273556
# 9991     0.099330
# 9992     0.469784
# 9993     1.076490
# 9997    -0.226548
# Length: 12328, dtype: float32

# %% [markdown]
# # Got Correlation to Work!!!!

# %%
broster= pd.concat([mean_a375, mean_A549],axis = 1)

# %%
broster.corr()
# Out:
#           0         1
# 0  1.000000  0.762024
# 1  0.762024  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.heatmap(broster.corr())
plt.show()

# %%
mean_A549.col_metadata_df = col_metadata_test_info

# %%
mean_A549.col_metadata_df
# Out:
# moa           HDAC inhibitor
# cell_iname              HME1
# Name: LTC002_HME1_3H:BRD-K81418486:10, dtype: object

# %%
bro = vorinostat_sig_id_info[["moa", "cell_iname"]]
#vorinostat_a375_gctoo.col_metadata_df

col_metadata_test_info= bro.iloc[1]

#col_metadata_test_info.set_index("sig_id", inplace=True)
# now the data frame is indexed by sig_ids consistent with those of the data_df:
col_metadata_test_info.index
# Out:
# Index(['moa', 'cell_iname'], dtype='object')

# %%
mean_a375.col_metadata_df = col_metadata_test_info

# %%
mean_a375.col_metadata_df
# Out:
# moa           HDAC inhibitor
# cell_iname              HME1
# Name: LTC002_HME1_3H:BRD-K81418486:10, dtype: object

# %%
mean_a375
# Out:
# cid
# ABY001_A375_XH:BRD-K81418486:0.625:24    0.295226
# ABY001_A375_XH:BRD-K81418486:0.625:3     0.034318
# ABY001_A375_XH:BRD-K81418486:10:24       0.423452
# ABY001_A375_XH:BRD-K81418486:10:3       -0.032881
# ABY001_A375_XH:BRD-K81418486:2.5:24      0.410430
#                                            ...
# LPROT002_A375_6H:BRD-K81418486:1         0.082050
# LPROT003_A375_6H:BRD-K81418486:1         0.242055
# PCL001_A375_24H:BRD-K81418486:10         0.523638
# PRISM001_A375_24H:BRD-K81418486:10       0.812149
# PRISM001_A375_6H:BRD-K81418486:10       -0.069238
# Length: 117, dtype: float32

# %%
mean_A549.row_metadata_df
# Out:
#           gene_symbol       ensembl_id  \
# gene_id
# 750          GAS8-AS1  ENSG00000221819
# 6315          ATXN8OS              NaN
# 7503             XIST  ENSG00000229807
# 8552             INE1  ENSG00000224975
# 9834           FAM30A  ENSG00000226777
# ...               ...              ...
# 100287932      TIMM23  ENSG00000265354
# 100289678      ZNF783  ENSG00000204946
# 100507436        MICA  ENSG00000204520
# 9142          TMEM257  ENSG00000221870
# 26148        C10orf12  ENSG00000155640
#
#                                                gene_title       gene_type  \
# gene_id
# 750                                  GAS8 antisense RNA 1           ncRNA
# 6315                         ATXN8 opposite strand lncRNA           ncRNA
# 7503                       X inactive specific transcript           ncRNA
# 8552                                inactivation escape 1           ncRNA
# 9834          family with sequence similarity 30 member A           ncRNA
# ...                                                   ...             ...
# 100287932  translocase of inner mitochondrial membrane 23  protein-coding
# 100289678                   zinc finger family member 783  protein-coding
# 100507436      MHC class I polypeptide-related sequence A  protein-coding
# 9142                            transmembrane protein 257  protein-coding
# 26148                 chromosome 10 open reading frame 12  protein-coding
#
#             src  feature_space
# gene_id
# 750        NCBI       inferred
# 6315       NCBI       inferred
# 7503       NCBI       inferred
# 8552       NCBI       inferred
# 9834       NCBI       inferred
# ...         ...            ...
# 100287932  NCBI  best inferred
# 100289678  NCBI  best inferred
# 100507436  NCBI  best inferred
# 9142       NCBI  best inferred
# 26148      NCBI  best inferred
#
# [12328 rows x 6 columns]

# %% [markdown]
# Got to figure out how to make up some kind of column meta_data so that concatenating is accepted. Look at concatenation steps documentation where it explains how it handles metadata

# %% [markdown]
# ### Checking the Correlation between Cell Lines

# %%
import cmapPy.pandasGEXpress.concat as cgad

# %%
bro = cgad.assemble_data([mean_a375, mean_A549], "horiz")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-337-4e0477d484d2> in <module>
# ----> 1 bro = cgad.assemble_data([mean_a375, mean_A549], "horiz")
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/concat.py in assemble_data(data_dfs, concat_direction)
#     472         n_cols = all_data_df.shape[1]
#     473         logger.debug("all_data_df.shape[1]: {}".format(n_cols))
# --> 474         n_cols_cumulative = sum([df.shape[1] for df in data_dfs])
#     475         assert n_cols == n_cols_cumulative
#     476
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/concat.py in <listcomp>(.0)
#     472         n_cols = all_data_df.shape[1]
#     473         logger.debug("all_data_df.shape[1]: {}".format(n_cols))
# --> 474         n_cols_cumulative = sum([df.shape[1] for df in data_dfs])
#     475         assert n_cols == n_cols_cumulative
#     476
#
# IndexError: tuple index out of range

# %%
# First concatenate
import cmapPy.pandasGEXpress.concat as cg 
# horizontally stack the two GCToo instances (note, you can also vertically stack)
HDAC_a375_gctoo = cg.hstack([mean_a375, mean_A549])

# Now we have a gctoo corresponding to two compounds, in one cell line: 
print("unique compound data present: ") 
print(HDAC_a375_gctoo.col_metadata_df["cmap_name"].unique())
print("unique cell line data present: ")
print(HDAC_a375_gctoo.col_metadata_df["cell_iname"].unique())

# Also note we still have the same genes as before, just with additional samples of data: 
print("combined gctoo expression data shape:")
print(HDAC_a375_gctoo.data_df.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-338-b813f6d83639> in <module>
#       2 import cmapPy.pandasGEXpress.concat as cg
#       3 # horizontally stack the two GCToo instances (note, you can also vertically stack)
# ----> 4 HDAC_a375_gctoo = cg.hstack([mean_a375, mean_A549])
#       5
#       6 # Now we have a gctoo corresponding to two compounds, in one cell line:
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/concat.py in hstack(gctoos, remove_all_metadata_fields, error_report_file, fields_to_remove, reset_ids)
#     195         col_meta_dfs.append(g.col_metadata_df)
#     196         data_dfs.append(g.data_df)
# --> 197         srcs.append(g.src)
#     198
#     199     logger.debug("shapes of row_meta_dfs:  {}".format([x.shape for x in row_meta_dfs]))
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'src'

# %%
mean_a375.data_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-6da1da820cc9> in <module>
# ----> 1 mean_a375.data_df
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'data_df'

# %%
Selected_10_moas_gctoo.data_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-1e9fee689579> in <module>
# ----> 1 Selected_10_moas_gctoo.data_df.shape
#
# NameError: name 'Selected_10_moas_gctoo' is not defined

# %%
Selected_10_moas_gctoo = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx",
                               ridx = landmark_gene_row_ids)
                               #cid = ids)
# Out:
# some of indexes being used to subset the data are not valid max N:  12328  out_of_range_ids:  [22794, 22796, 22809, 22823, 22827, 22841, 22883, 22887, 22889, 22905, 22908, 22926, 22934, 23011, 23013, 23014, 23029, 23038, 23039, 23061, 23076, 23077, 23097, 23131, 23139, 23142, 23149, 23161, 23200, 23210, 23212, 23223, 23224, 23244, 23271, 23300, 23321, 23325, 23326, 23335, 23338, 23365, 23368, 23378, 23386, 23410, 23443, 23463, 23499, 23512, 23522, 23530, 23536, 23585, 23588, 23597, 23635, 23636, 23647, 23658, 23659, 23670, 24149, 25793, 25803, 25805, 25825, 25839, 25874, 25932, 25966, 25976, 25987, 26001, 26020, 26036, 26054, 26064, 26128, 26136, 26227, 26292, 26511, 26520, 26993, 27032, 27095, 27109, 27242, 27244, 27336, 27346, 28969, 29082, 29083, 29103, 29763, 29890, 29911, 29916, 29928, 29937, 29978, 30001, 30836, 30849, 50810, 50813, 50814, 50865, 51001, 51005, 51015, 51021, 51024, 51026, 51031, 51053, 51056, 51070, 51071, 51097, 51116, 51160, 51170, 51203, 51282, 51293, 51335, 51375, 51382, 51385, 51422, 51465, 51466, 51495, 51569, 51599, 51635, 51719, 51742, 53343, 54205, 54386, 54438, 54442, 54499, 54505, 54512, 54541, 54623, 54681, 54733, 54807, 54850, 54881, 54915, 54957, 55008, 55011, 55012, 55033, 55038, 55111, 55127, 55129, 55148, 55179, 55256, 55324, 55556, 55604, 55608, 55620, 55699, 55746, 55748, 55793, 55818, 55825, 55837, 55847, 55893, 55958, 56654, 56889, 56924, 56940, 56997, 57019, 57048, 57147, 57149, 57178, 57192, 57215, 57406, 57761, 57804, 58472, 58478, 58497, 58533, 60493, 60528, 63874, 63933, 64080, 64422, 64428, 64429, 64746, 64781, 64943, 65057, 65123, 66008, 79006, 79071, 79073, 79080, 79090, 79094, 79143, 79170, 79174, 79187, 79600, 79643, 79716, 79850, 79902, 79921, 79947, 79961, 80204, 80212, 80347, 80349, 80746, 80758, 81533, 81544, 83743, 84159, 84617, 84722, 84890, 85236, 85377, 89910, 90861, 91137, 91949, 93487, 93594, 94239, 116832, 124583, 147179, 148022, 200081, 200734, 256364, 375346, 388650]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-23-50858256e33f> in <module>
#       1 Selected_10_moas_gctoo = parse("/scratch2-shared/erikep/level5_beta_trt_cp_n720216x12328.gctx",
# ----> 2                                ridx = landmark_gene_row_ids)
#       3                                #cid = ids)
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/parse.py in parse(file_path, convert_neg_666, rid, cid, ridx, cidx, row_meta_only, col_meta_only, make_multiindex)
#      66                               rid=rid, cid=cid, ridx=ridx, cidx=cidx,
#      67                               row_meta_only=row_meta_only, col_meta_only=col_meta_only,
# ---> 68                               make_multiindex=make_multiindex)
#      69
#      70     else:
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/parse_gctx.py in parse(gctx_file_path, convert_neg_666, rid, cid, ridx, cidx, row_meta_only, col_meta_only, make_multiindex)
#     105
#     106         # validate optional input ids & get indexes to subset by
# --> 107         (sorted_ridx, sorted_cidx) = check_and_order_id_inputs(rid, ridx, cid, cidx, row_meta, col_meta)
#     108
#     109         data_dset = gctx_file[data_node]
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/parse_gctx.py in check_and_order_id_inputs(rid, ridx, cid, cidx, row_meta_df, col_meta_df)
#     141     (col_type, col_ids) = check_id_idx_exclusivity(cid, cidx)
#     142
# --> 143     row_ids = check_and_convert_ids(row_type, row_ids, row_meta_df)
#     144     ordered_ridx = get_ordered_idx(row_type, row_ids, row_meta_df)
#     145
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/parse_gctx.py in check_and_convert_ids(id_type, id_list, meta_df)
#     179             check_id_validity(id_list, meta_df)
#     180         else:
# --> 181             check_idx_validity(id_list, meta_df)
#     182         return id_list
#     183     else:
#
# ~/.local/lib/python3.6/site-packages/cmapPy/pandasGEXpress/parse_gctx.py in check_idx_validity(id_list, meta_df)
#     203                                                                                                                      out_of_range_ids)
#     204         logger.error(msg)
# --> 205         raise Exception("parse_gctx check_idx_validity " + msg)
#     206
#     207
#
# Exception: parse_gctx check_idx_validity some of indexes being used to subset the data are not valid max N:  12328  out_of_range_ids:  [22794, 22796, 22809, 22823, 22827, 22841, 22883, 22887, 22889, 22905, 22908, 22926, 22934, 23011, 23013, 23014, 23029, 23038, 23039, 23061, 23076, 23077, 23097, 23131, 23139, 23142, 23149, 23161, 23200, 23210, 23212, 23223, 23224, 23244, 23271, 23300, 23321, 23325, 23326, 23335, 23338, 23365, 23368, 23378, 23386, 23410, 23443, 23463, 23499, 23512, 23522, 23530, 23536, 23585, 23588, 23597, 23635, 23636, 23647, 23658, 23659, 23670, 24149, 25793, 25803, 25805, 25825, 25839, 25874, 25932, 25966, 25976, 25987, 26001, 26020, 26036, 26054, 26064, 26128, 26136, 26227, 26292, 26511, 26520, 26993, 27032, 27095, 27109, 27242, 27244, 27336, 27346, 28969, 29082, 29083, 29103, 29763, 29890, 29911, 29916, 29928, 29937, 29978, 30001, 30836, 30849, 50810, 50813, 50814, 50865, 51001, 51005, 51015, 51021, 51024, 51026, 51031, 51053, 51056, 51070, 51071, 51097, 51116, 51160, 51170, 51203, 51282, 51293, 51335, 51375, 51382, 51385, 51422, 51465, 51466, 51495, 51569, 51599, 51635, 51719, 51742, 53343, 54205, 54386, 54438, 54442, 54499, 54505, 54512, 54541, 54623, 54681, 54733, 54807, 54850, 54881, 54915, 54957, 55008, 55011, 55012, 55033, 55038, 55111, 55127, 55129, 55148, 55179, 55256, 55324, 55556, 55604, 55608, 55620, 55699, 55746, 55748, 55793, 55818, 55825, 55837, 55847, 55893, 55958, 56654, 56889, 56924, 56940, 56997, 57019, 57048, 57147, 57149, 57178, 57192, 57215, 57406, 57761, 57804, 58472, 58478, 58497, 58533, 60493, 60528, 63874, 63933, 64080, 64422, 64428, 64429, 64746, 64781, 64943, 65057, 65123, 66008, 79006, 79071, 79073, 79080, 79090, 79094, 79143, 79170, 79174, 79187, 79600, 79643, 79716, 79850, 79902, 79921, 79947, 79961, 80204, 80212, 80347, 80349, 80746, 80758, 81533, 81544, 83743, 84159, 84617, 84722, 84890, 85236, 85377, 89910, 90861, 91137, 91949, 93487, 93594, 94239, 116832, 124583, 147179, 148022, 200081, 200734, 256364, 375346, 388650]

# %%
Selected_10_moas_gctoo.data_df.shape

# %%
Selected_10_moas_gctoo.col_metadata_df[0:5]

# %% [markdown]
# not looking like it is supposed to

# %%
import cmapPy.pandasGEXpress.subset_gctoo as sg
Selected_10_moas_gctoo.col_metadata_df["cell_iname"] == "A375"

# %%
Selected_10_moas_gctoo.col_metadata_df[0:5]
# Out:
# Empty DataFrame
# Columns: []
# Index: [ABY001_A375_XH:BRD-A61304759:0.625:24, ABY001_A375_XH:BRD-A61304759:0.625:3, ABY001_A375_XH:BRD-A61304759:10:24, ABY001_A375_XH:BRD-A61304759:10:3, ABY001_A375_XH:BRD-A61304759:2.5:24]

# %%
# first, get the cid values we want to keep 
cyclo_a375_ids = Selected_10_moas_gctoo.col_metadata_df.index[Selected_10_moas_gctoo.col_metadata_df["cell_iname"] == "A375"]

# subset GCToo instance to only include these values 
Selected_10_moas_gctoo = sg.subset_gctoo(Selected_10_moas_gctoo, cid=vorinostat_a375_ids)

# Now, our samples only correspond to one cell type: A375
Selected_10_moas_gctoo.col_metadata_df["cell_iname"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cell_iname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-3f97d436c6bb> in <module>
#       1 # first, get the cid values we want to keep
# ----> 2 cyclo_a375_ids = Selected_10_moas_gctoo.col_metadata_df.index[Selected_10_moas_gctoo.col_metadata_df["cell_iname"] == "A375"]
#       3
#       4 # subset GCToo instance to only include these values
#       5 Selected_10_moas_gctoo = sg.subset_gctoo(Selected_10_moas_gctoo, cid=vorinostat_a375_ids)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'cell_iname'

# %%
# parse rows
# Check to make sure we only have 978 rows of expression data: 
landmark_only_gctoo.data_df.shape #yup!

# %% [markdown]
# Psuedo_Code
# 1. Split the MoAs into their separate cell lines.
# 2. Check number of transcriptomic profiles per cell line
# 2. Mean expression over all of the samples of a population for each MoA
# (vorinostat_a375_gctoo.data_df.mean(axis = 0))
# 3. Do a correlation test between the various samples
# (vorinostat_a375_cors = vorinostat_a375_gctoo.data_df.corr())
# (import seaborn as sns
# import matplotlib.pyplot as plt
# sns.set()
#
# sns.heatmap(vorinostat_a375_gctoo.data_df.corr(), cmap='plasma')
# plt.show())

# %% [markdown]
# ## Split single MoA into separate cell lines

# %%
Selected_10_moas_gctoo.col_metadata_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [BRAF001_A375_24H:BRD-K39339537-001-16-0:0.15625, BRAF001_A375_24H:BRD-K39339537-001-16-0:0.625, BRAF001_A375_24H:BRD-K39339537-001-16-0:10, BRAF001_A375_24H:BRD-K39339537-001-16-0:2.5, BRAF001_A375_24H:BRD-K92778217-001-21-0:0.15625, BRAF001_A375_24H:BRD-K92778217-001-21-0:0.625, BRAF001_A375_24H:BRD-K92778217-001-21-0:10, BRAF001_A375_24H:BRD-K92778217-001-21-0:2.5, BRAF001_A375_6H:BRD-K39339537-001-16-0:0.15625, BRAF001_A375_6H:BRD-K39339537-001-16-0:0.625, BRAF001_A375_6H:BRD-K39339537-001-16-0:10, BRAF001_A375_6H:BRD-K39339537-001-16-0:2.5, BRAF001_A375_6H:BRD-K92778217-001-21-0:0.15625, BRAF001_A375_6H:BRD-K92778217-001-21-0:0.625, BRAF001_A375_6H:BRD-K92778217-001-21-0:10, BRAF001_A375_6H:BRD-K92778217-001-21-0:2.5, BRAF001_HEK293T_24H:BRD-K39339537-001-16-0:0.15625, BRAF001_HEK293T_24H:BRD-K39339537-001-16-0:0.625, BRAF001_HEK293T_24H:BRD-K39339537-001-16-0:10, BRAF001_HEK293T_24H:BRD-K39339537-001-16-0:2.5, BRAF001_HEK293T_24H:BRD-K92778217-001-21-0:0.15625, BRAF001_HEK293T_24H:BRD-K92778217-001-21-0:0.625, BRAF001_HEK293T_24H:BRD-K92778217-001-21-0:10, BRAF001_HEK293T_24H:BRD-K92778217-001-21-0:2.5, BRAF001_HEK293T_6H:BRD-K39339537-001-16-0:0.15625, BRAF001_HEK293T_6H:BRD-K39339537-001-16-0:0.625, BRAF001_HEK293T_6H:BRD-K39339537-001-16-0:10, BRAF001_HEK293T_6H:BRD-K39339537-001-16-0:2.5, BRAF001_HEK293T_6H:BRD-K92778217-001-21-0:0.15625, BRAF001_HEK293T_6H:BRD-K92778217-001-21-0:0.625, BRAF001_HEK293T_6H:BRD-K92778217-001-21-0:10, BRAF001_HEK293T_6H:BRD-K92778217-001-21-0:2.5, CPC001_HA1E_24H:BRD-A87479750-001-01-9:10, CPC001_HA1E_24H:BRD-A98378129-001-01-4:10, CPC001_HA1E_6H:BRD-A87479750-001-01-9:10, CPC001_HA1E_6H:BRD-A98378129-001-01-4:10, CPC001_HCC515_24H:BRD-A87479750-001-01-9:10, CPC001_HCC515_24H:BRD-A98378129-001-01-4:10, CPC001_HCC515_6H:BRD-A87479750-001-01-9:10, CPC001_HCC515_6H:BRD-A98378129-001-01