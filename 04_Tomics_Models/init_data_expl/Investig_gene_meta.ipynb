# %%
import pandas as pd

# %%
# Here we get gene information, but unsure exactly what this is. It's not expression data. Looks like the sets of genes associated with
# one purturbation
clue_gene = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/04_Tomics_Models/init_data_expl/clue_geneinfo_beta.txt', delimiter = "\t")

# %%
clue_gene[:10]
# Out:
#    gene_id gene_symbol       ensembl_id  \
# 0      750    GAS8-AS1  ENSG00000221819
# 1     6315     ATXN8OS              NaN
# 2     7503        XIST  ENSG00000229807
# 3     8552        INE1  ENSG00000224975
# 4     9834      FAM30A  ENSG00000226777
# 5    10141   LINC01587  ENSG00000082929
# 6    10255        HCG9  ENSG00000204625
# 7    10281       DSCR4  ENSG00000184029
# 8    23434   LINC01565  ENSG00000198685
# 9    23591     FAM215A  ENSG00000267496
#
#                                      gene_title gene_type   src feature_space
# 0                          GAS8 antisense RNA 1     ncRNA  NCBI      inferred
# 1                  ATXN8 opposite strand lncRNA     ncRNA  NCBI      inferred
# 2                X inactive specific transcript     ncRNA  NCBI      inferred
# 3                         inactivation escape 1     ncRNA  NCBI      inferred
# 4   family with sequence similarity 30 member A     ncRNA  NCBI      inferred
# ...

# %%
clue_gene.columns
# Out:
# Index(['gene_id', 'gene_symbol', 'ensembl_id', 'gene_title', 'gene_type',
#        'src', 'feature_space'],
#       dtype='object')

# %%
clue_gene.shape
# Out:
# (12328, 7)

# %%
clue_gene = clue_gene[clue_gene.feature_space == "landmark"]

# %%
clue_gene
# Out:
#       gene_id gene_symbol       ensembl_id  \
# 2154       16        AARS  ENSG00000090861
# 2155       23       ABCF1  ENSG00000204574
# 2156       25        ABL1  ENSG00000097007
# 2157       30       ACAA1  ENSG00000060971
# 2158       39       ACAT2  ENSG00000120437
# ...       ...         ...              ...
# 3127   200081       TXLNA  ENSG00000084652
# 3128   200734      SPRED2  ENSG00000198369
# 3129   256364        EML3  ENSG00000149499
# 3130   375346     STIMATE  ENSG00000213533
# 3131   388650      DIPK1A  ENSG00000154511
#
#                                              gene_title       gene_type   src  \
# 2154                             alanyl-tRNA synthetase  protein-coding  NCBI
# 2155          ATP binding cassette subfamily F member 1  protein-coding  NCBI
# 2156  ABL proto-oncogene 1, non-receptor tyrosine ki...  protein-coding  NCBI
# 2157                       acetyl-CoA acyltransferase 1  protein-coding  NCBI
# ...

# %% [markdown]
# ## Things to Try
# 1. We could start by just looking at the genes from the transcriptomic profiles that are landmark genes, since the others are inferred from these genes anyway.
# 2. Then use the transcriptomic profiles from the 10 MoAs with the most different type of compounds
# 3. For a single compound, we could see how the average transcriptomic values for a single MoA ranges over different cell lines using the landmark genes.
#     - if there isn't a correlation, could mean a lot of noise due to the signal coming from the cell lines
#     - if there is a correlation, would support that we could use multiple cell lines to draw conclusions about the MoA
# 4. Then implement an adapted version of the second place solution found on kaggle (maybe the first if I understand)
#     - remove cell viability data
#     - adapt input
