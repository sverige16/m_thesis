# %%
import pandas as pd

# %%
# Download compounds that were used to perturb cells for HIC from first batch that comes from PharmBio Lab
cellinfo = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/04_Tomics_Models/init_data_expl/clue_cellinfo_beta.txt', sep='\t')

# %%
cellinfo.head(10)
# Out:
#   cell_iname cellosaurus_id donor_age  donor_age_death  \
# 0       1HAE            NaN       NaN              NaN
# 1       AALE            NaN       NaN              NaN
# 2  AG06263_2            NaN       NaN              NaN
# 3  AG06840_A            NaN       NaN              NaN
# 4  AG078N1_1            NaN       NaN              NaN
# 5        C42            NaN       NaN              NaN
# 6       CD34            NaN       NaN              NaN
# 7       HAP1            NaN       NaN              NaN
# 8    HEK293T            NaN       NaN              NaN
# 9    HIMG001            NaN       NaN              NaN
#
#    donor_disease_age_onset doubling_time growth_medium provider_catalog_id  \
# 0                      NaN           NaN           NaN                 NaN
# 1                      NaN           NaN           NaN                 NaN
# 2                      NaN           NaN           NaN                 NaN
# ...

# %%
cellinfo.shape
# Out:
# (240, 20)

# %%
cellinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cell_iname               240 non-null    object
#  1   cellosaurus_id           151 non-null    object
#  2   donor_age                83 non-null     object
#  3   donor_age_death          0 non-null      float64
#  4   donor_disease_age_onset  0 non-null      float64
#  5   doubling_time            145 non-null    object
#  6   growth_medium            144 non-null    object
#  7   provider_catalog_id      72 non-null     object
#  8   feature_id               92 non-null     object
#  9   cell_type                240 non-null    object
#  10  donor_ethnicity          240 non-null    object
#  11  donor_sex                240 non-null    object
#  12  donor_tumor_phase        240 non-null    object
#  13  cell_lineage             240 non-null    object
# ...

# %%
cell_lines = cellinfo["cell_iname"].to_list()

# %%
print(sorted(cell_lines))
# Out:
# ['1HAE', '22RV1', '5637', 'A204', 'A375', 'A549', 'A673', 'AALE', 'AG06263_2', 'AG06840_A', 'AG078N1_1', 'AGS', 'AN3CA', 'ASC', 'BC3C', 'BEN', 'BICR6', 'BJAB', 'BT20', 'BT474', 'C42', 'CAL29', 'CD34', 'CJM', 'CL34', 'CORL23', 'COV434', 'COV644', 'CW2', 'DLD1', 'DU145', 'DV90', 'EFO27', 'ES2', 'G401', 'GI1', 'GP2D', 'H1299', 'H1975', 'HA1E', 'HAP1', 'HBL1', 'HCC15', 'HCC1588', 'HCC44', 'HCC515', 'HCC827', 'HCC95', 'HCT116', 'HEC108', 'HEC151', 'HEC1A', 'HEC251', 'HEC265', 'HEK293', 'HEK293T', 'HEKTE', 'HELA', 'HEPG2', 'HFL1', 'HIMG001', 'HIMG002', 'HL60', 'HME', 'HME1', 'HMELZ', 'HPTEC', 'HS27A', 'HS578T', 'HT115', 'HT29', 'HUES3', 'HUH7', 'HUH751', 'HUVEC', 'IGR37', 'IM95', 'IMR90', 'IPS-15-2', 'IPS-3', 'IPS-ND34732', 'J82', 'JHH5', 'JHH7', 'JHUEM2', 'JURKAT', 'K562', 'KMS34', 'LHSAR', 'LN229', 'LNCAP', 'LOVO', 'MCF10A', 'MCF7', 'MCH58', 'MCLF0067SZ', 'MCLF015CN', 'MCLF022CN', 'MCLF027CN', 'MCLF033SZ', 'MCLF035SZ', 'MCLF037SZ', 'MCLF040SZ', 'MCLF051CN', 'MCLF054CN', 'MCLF056CN', 'MCL
# ...

# %% [markdown]
#  Conclusion: There does exist transcriptomic profiles from U2O cells
