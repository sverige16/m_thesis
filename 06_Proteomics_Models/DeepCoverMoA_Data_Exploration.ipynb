# %%
import pandas as pd
import numpy as np
import os
import cv2
import tqdm
import glob

# %%
 moas = ['Aurora kinase inhibitor', 'tubulin polymerization inhibitor', 'JAK inhibitor', 'protein synthesis inhibitor', 'HDAC inhibitor', 
        'topoisomerase inhibitor', 'PARP inhibitor', 'ATPase inhibitor', 'retinoid receptor agonist', 'HSP inhibitor']

# %%
# Download compounds that were used to perturb cells for HIC from first batch that comes from PharmBio Lab
compounds = pd.read_csv('/home/jovyan/scratch-shared/erik/from_phil/specs935-v1-compounds.csv', sep=',')
compounds.shape
# Out:
# (935, 39)

# %%
# Download all the compounds that exist on CLUE --> gene expression data from LINCS
# from https://clue.io/
clue_compounds = pd.read_csv('/home/jovyan/scratch-shared/erik/from_phil/clue_compoundinfo_beta.txt', delimiter = "\t")

# %% [markdown]
# ## Clue Compounds

# %%
clue_compounds
# Out:
#              pert_id      cmap_name target  \
# 0      BRD-A08715367     L-theanine    NaN
# 1      BRD-A12237696   L-citrulline    NaN
# 2      BRD-A18795974  BRD-A18795974    NaN
# 3      BRD-A27924917  BRD-A27924917    NaN
# 4      BRD-A35931254  BRD-A35931254    NaN
# ...              ...            ...    ...
# 39316  BRD-K62685538    triptorelin  GNRHR
# 39317  BRD-K62221994        T-98475  GNRHR
# 39318  BRD-K53397409   benzoic-acid  RAB9A
# 39319  BRD-A62182663        YK-4279   DHX9
# 39320  BRD-A62182663        YK-4279   FLI1
#
#                                                      moa  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39316  Gonadotropin releasing factor hormone receptor...
# 39317  Gonadotropin releasing factor hormone receptor...
# 39318  Precursor for food preservatives, plasticizers...
# 39319  Binding of RNA helicase A to the transcription...
# 39320  Binding of RNA helicase A to the transcription...
#
#                                         canonical_smiles  \
# 0                                   CCNC(=O)CCC(N)C(O)=O
# 1                                   NC(CCCNC(N)=O)C(O)=O
# 2                             CCCN(CCC)C1CCc2ccc(O)cc2C1
# 3                        NCC(O)(CS(O)(=O)=O)c1ccc(Cl)cc1
# 4                     CN1CCc2cccc-3c2C1Cc1ccc(O)c(O)c-31
# ...                                                  ...
# 39316  CC(C)C[C@H](NC(=O)[C@@H](Cc1c[nH]c2ccccc12)NC(...
# 39317  CC(C)OC(=O)c1cn(Cc2c(F)cccc2F)c3sc(c(CN(C)Cc4c...
# 39318                                     OC(=O)c1ccccc1
# 39319       COc1ccc(cc1)C(=O)CC1(O)C(=O)Nc2c1c(Cl)ccc2Cl
# 39320       COc1ccc(cc1)C(=O)CC1(O)C(=O)Nc2c1c(Cl)ccc2Cl
#
#                          inchi_key   compound_aliases
# 0      DATAGRPVKZEWHA-UHFFFAOYSA-N         l-theanine
# 1      RHGKLRLOHDJJDR-UHFFFAOYSA-N       l-citrulline
# 2      BLYMJBIZMIGWFK-UHFFFAOYSA-N     7-hydroxy-DPAT
# 3      WBSMZVIMANOCNX-UHFFFAOYSA-N  2-hydroxysaclofen
# 4      VMWNQDUVQKEIOC-UHFFFAOYSA-N   r(-)-apomorphine
# ...                            ...                ...
# 39316  VXKHXGOKWPXYNA-PGBVPBMZSA-N                NaN
# 39317  RANJJVIMTOIWIN-UHFFFAOYSA-N                NaN
# 39318  WPYMKLBDIGXBTP-UHFFFAOYSA-N                NaN
# 39319  HLXSCTYHLQHQDJ-UHFFFAOYSA-N                NaN
# 39320  HLXSCTYHLQHQDJ-UHFFFAOYSA-N                NaN
#
# [39321 rows x 7 columns]

# %%
clue_compounds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39321 entries, 0 to 39320
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pert_id           39321 non-null  object
#  1   cmap_name         39321 non-null  object
#  2   target            8046 non-null   object
#  3   moa               8046 non-null   object
#  4   canonical_smiles  33531 non-null  object
#  5   inchi_key         26838 non-null  object
#  6   compound_aliases  855 non-null    object
# dtypes: object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# Looks like 39321 different molecules, but we only have 8046 with an identifiable MoA

# %%
# Remove all the BRD from the unique code to identify common compounds that the Broad Institute places on there.
clue_compounds['pert_id'] =  clue_compounds['pert_id'].map(lambda x: x.lstrip('BRD-'))

# %%
clue_compounds[0:10]
# Out:
#      pert_id               cmap_name target  moa  \
# 0  A08715367              L-theanine    NaN  NaN
# 1  A12237696            L-citrulline    NaN  NaN
# 2  A18795974           BRD-A18795974    NaN  NaN
# 3  A27924917           BRD-A27924917    NaN  NaN
# 4  A35931254           BRD-A35931254    NaN  NaN
# 5  A39230911            chlorphensin    NaN  NaN
# 6  A77577770           BRD-A77577770    NaN  NaN
# 7  A86415025           BRD-A86415025    NaN  NaN
# 8  K05674516                PSI-7976    NaN  NaN
# 9  K10673031  S-isopropylisothiourea    NaN  NaN
#
#                                     canonical_smiles  \
# 0                               CCNC(=O)CCC(N)C(O)=O
# 1                               NC(CCCNC(N)=O)C(O)=O
# 2                         CCCN(CCC)C1CCc2ccc(O)cc2C1
# 3                    NCC(O)(CS(O)(=O)=O)c1ccc(Cl)cc1
# 4                 CN1CCc2cccc-3c2C1Cc1ccc(O)c(O)c-31
# 5                         NC(=O)OCC(O)COc1ccc(Cl)cc1
# 6        CCCCCCCCCCCCCCCC(=O)OC(CC(O)=O)C[N+](C)(C)C
# 7                     C(C(N1CCCCC1)c1ccccc1)c1ccccc1
# 8  CC(C)OC(=O)[C@H](C)N[P@@](=O)(OC[C@H]1O[C@@H](...
# 9                                       CC(C)SC(N)=N
#
#                      inchi_key                       compound_aliases
# 0  DATAGRPVKZEWHA-UHFFFAOYSA-N                             l-theanine
# 1  RHGKLRLOHDJJDR-UHFFFAOYSA-N                           l-citrulline
# 2  BLYMJBIZMIGWFK-UHFFFAOYSA-N                         7-hydroxy-DPAT
# 3  WBSMZVIMANOCNX-UHFFFAOYSA-N                      2-hydroxysaclofen
# 4  VMWNQDUVQKEIOC-UHFFFAOYSA-N                       r(-)-apomorphine
# 5  SKPLBLUECSEIFO-UHFFFAOYSA-N                chlorphenesin-carbamate
# 6  XOMRRQXKHMYMOC-UHFFFAOYSA-O                     palmitoylcarnitine
# 7  JQWJJJYHVHNXJH-UHFFFAOYSA-N  1-(1,2-diphenylethyl)piperidine-(+/-)
# 8  TTZHDVOVKQGIBA-YBSJRAAASA-N                             sofosbuvir
# 9  XSSNABKEYXKKMK-UHFFFAOYSA-N                 s-isopropylisothiourea

# %%
clue_compounds = list(clue_compounds['pert_id'])

# %% [markdown]
# ## SPECS V1 only Compounds

# %%
# If the ID in compounds is in the list of clue compounds, include it in a new data frame. 
compounds_wge = compounds[compounds.CUSTOMER_ID.isin(clue_compounds)].reset_index(drop=True)

# %%
compounds_wge
# Out:
#     Library Compound ID   Batch nr CUSTOMER_ID            MOLFORMULA  \
# 0     SPECS   CBK290537  BJ1898259   A39052811  C21H25ClFN3O3.C6H8O7
# 1     SPECS   CBK200938  BJ1897571   A84465106            C20H24N2O6
# 2     SPECS   CBK290948  BJ1899032   K05977823           C20H23N3O2S
# 3     SPECS   CBK200855  BJ1895358   K09255212             C9H5ClINO
# 4     SPECS   CBK015802  BJ1895142   K17075857             C9H5Cl2NO
# ..      ...         ...        ...         ...                   ...
# 639   SPECS   CBK291076  BJ1895025   K30126819          C4H8O6S4.2Na
# 640   SPECS   CBK307747  BJ1894364   K61195623              C18H20O5
# 641   SPECS   CBK307964  BJ1895783   K59753975      C43H55N5O7.H2SO4
# 642   SPECS   CBK309391  BJ1897986   K78567475           C42H68N6O6S
# 643   SPECS   CBK309437  BJ1898432   K23363278            C24H30N6O2
#
#      MOLWEIGHT               NAME                         VENDOR  \
# 0       614.03  Mosapride citrate              Selleck Chemicals
# 1       388.42        Nisoldipine                 MedChemExpress
# 2       369.49          Tenovin-1              Selleck Chemicals
# 3       305.50         CLIOQUINOL  Microsource Discovery Systems
# 4       214.05         CHLOROXINE  Microsource Discovery Systems
# ..         ...                ...                            ...
# 639     326.34            DIMESNA  Microsource Discovery Systems
# 640     316.36  Combretastatin-A4                Axon Medchem BV
# 641     852.03  Vindesine Sulfate             Avachem Scientific
# 642     785.11        Dolastin-10      Shanghai PI Chemicals Ltd
# 643     434.55             CYT997              Selleck Chemicals
#
#                                    ADD_INFO  \
# 0                               112885-42-4
# 1    CAS 63675-72-9, target Calcium Channel
# 2                               380315-80-0
# 3                                  130-26-7
# 4                                  773-76-2
# ..                                      ...
# 639                              16208-51-8
# 640                         CAS 117048-59-6
# 641                              59917-39-4
# 642                                NotKnown
# 643                             917111-44-5
#
#                                                 SMILES  ... PUBCHEM_CID  \
# 0      CCOc1cc(N)c(Cl)cc1C(=O)NCC1CN(Cc2ccc(F)cc2)CCO1  ...    119583.0
# 1    O=C(C1=C(C)NC(C)=C(C(OCC(C)C)=O)C1C2=CC=CC=C2[...  ...      4499.0
# 2      CC(=O)Nc1ccc(NC(=S)NC(=O)c2ccc(cc2)C(C)(C)C)cc1  ...   1013376.0
# 3                               Oc1c(I)cc(Cl)c2cccnc12  ...      2788.0
# 4                              Oc1c(Cl)cc(Cl)c2cccnc12  ...      2722.0
# ..                                                 ...  ...         ...
# 639                         OS(=O)(=O)CCSSCCS(O)(=O)=O  ...         NaN
# 640             COc1ccc(\C=C/c2cc(OC)c(OC)c(OC)c2)cc1O  ...         NaN
# 641  CC[C@]1(O)C[C@H]2CN(C1)CCc1c([nH]c3ccccc13)[C@...  ...         NaN
# 642  CC[C@H](C)[C@@H]([C@@H](CC(=O)N1CCC[C@H]1[C@H]...  ...         NaN
# 643  CCC[C@H](Nc1nc(ncc1C)-c1ccc(NC(=O)NCC)c(OC)c1)...  ...         NaN
#
#      PUBCHEM_SID PURITY_RATING PURITY_RATING_4M      TOX21_ID DILIST_ID  \
# 0    144205427.0             A                A  Tox21_111874       NaN
# 1    144205804.0             F               Fc  Tox21_112251       NaN
# 2    144206362.0             W              NaN  Tox21_112809       NaN
# 3    144203967.0             A                A  Tox21_110416       NaN
# 4    144205047.0             A                A  Tox21_111494       NaN
# ..           ...           ...              ...           ...       ...
# 639          NaN           NaN              NaN           NaN       NaN
# 640          NaN           NaN              NaN           NaN       NaN
# 641          NaN           NaN              NaN           NaN       NaN
# 642          NaN           NaN              NaN           NaN       NaN
# 643          NaN           NaN              NaN           NaN       NaN
#
#     DILIst Classification Routs of Administration  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ..                    ...                     ...
# 639                   NaN                     NaN
# 640                   NaN                     NaN
# 641                   NaN                     NaN
# 642                   NaN                     NaN
# 643                   NaN                     NaN
#
#     selected_mechanism of action (MoA)                 selected_mechanism
# 0           serotonin receptor agonist  aryl hydrocarbon receptor agonist
# 1              calcium channel blocker  aryl hydrocarbon receptor agonist
# 2        SIRT inhibitor|TP53 activator  aryl hydrocarbon receptor agonist
# 3                      chelating agent  aryl hydrocarbon receptor agonist
# 4           opioid receptor antagonist  aryl hydrocarbon receptor agonist
# ..                                 ...                                ...
# 639   tubulin polymerization inhibitor   tubulin polymerization inhibitor
# 640   tubulin polymerization inhibitor   tubulin polymerization inhibitor
# 641   tubulin polymerization inhibitor   tubulin polymerization inhibitor
# 642   tubulin polymerization inhibitor   tubulin polymerization inhibitor
# 643   tubulin polymerization inhibitor   tubulin polymerization inhibitor
#
# [644 rows x 39 columns]

# %% [markdown]
#  Means that there are 644 compounds that have induced gene expression profiles and HCI in SPECS V1

# %%
compounds_wge[:5]
# Out:
#   Library Compound ID   Batch nr CUSTOMER_ID            MOLFORMULA  MOLWEIGHT  \
# 0   SPECS   CBK290537  BJ1898259   A39052811  C21H25ClFN3O3.C6H8O7     614.03
# 1   SPECS   CBK200938  BJ1897571   A84465106            C20H24N2O6     388.42
# 2   SPECS   CBK290948  BJ1899032   K05977823           C20H23N3O2S     369.49
# 3   SPECS   CBK200855  BJ1895358   K09255212             C9H5ClINO     305.50
# 4   SPECS   CBK015802  BJ1895142   K17075857             C9H5Cl2NO     214.05
#
#                 NAME                         VENDOR  \
# 0  Mosapride citrate              Selleck Chemicals
# 1        Nisoldipine                 MedChemExpress
# 2          Tenovin-1              Selleck Chemicals
# 3         CLIOQUINOL  Microsource Discovery Systems
# 4         CHLOROXINE  Microsource Discovery Systems
#
#                                  ADD_INFO  \
# 0                             112885-42-4
# 1  CAS 63675-72-9, target Calcium Channel
# 2                             380315-80-0
# 3                                130-26-7
# 4                                773-76-2
#
#                                               SMILES  ... PUBCHEM_CID  \
# 0    CCOc1cc(N)c(Cl)cc1C(=O)NCC1CN(Cc2ccc(F)cc2)CCO1  ...    119583.0
# 1  O=C(C1=C(C)NC(C)=C(C(OCC(C)C)=O)C1C2=CC=CC=C2[...  ...      4499.0
# 2    CC(=O)Nc1ccc(NC(=S)NC(=O)c2ccc(cc2)C(C)(C)C)cc1  ...   1013376.0
# 3                             Oc1c(I)cc(Cl)c2cccnc12  ...      2788.0
# 4                            Oc1c(Cl)cc(Cl)c2cccnc12  ...      2722.0
#
#    PUBCHEM_SID PURITY_RATING PURITY_RATING_4M      TOX21_ID DILIST_ID  \
# 0  144205427.0             A                A  Tox21_111874       NaN
# 1  144205804.0             F               Fc  Tox21_112251       NaN
# 2  144206362.0             W              NaN  Tox21_112809       NaN
# 3  144203967.0             A                A  Tox21_110416       NaN
# 4  144205047.0             A                A  Tox21_111494       NaN
#
#   DILIst Classification Routs of Administration  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN
#
#   selected_mechanism of action (MoA)                 selected_mechanism
# 0         serotonin receptor agonist  aryl hydrocarbon receptor agonist
# 1            calcium channel blocker  aryl hydrocarbon receptor agonist
# 2      SIRT inhibitor|TP53 activator  aryl hydrocarbon receptor agonist
# 3                    chelating agent  aryl hydrocarbon receptor agonist
# 4         opioid receptor antagonist  aryl hydrocarbon receptor agonist
#
# [5 rows x 39 columns]

# %%
# For all the compounds in the original chosen group, see how many compounds with the same MOA 
# we have in each of our two data frames.
compounds[compounds.moa.isin(moas)].moa.value_counts()
# Out:
# HDAC inhibitor                      33
# topoisomerase inhibitor             32
# HSP inhibitor                       24
# protein synthesis inhibitor         23
# JAK inhibitor                       22
# PARP inhibitor                      21
# Aurora kinase inhibitor             20
# tubulin polymerization inhibitor    20
# retinoid receptor agonist           20
# ATPase inhibitor                    19
# Name: moa, dtype: int64

# %%
# For all the compounds where the compounds are identical for creating morphological and transcriptomic profiles,
# see how many compounds with the same MOA we have in each of our two data frames.
compounds_wge[compounds_wge.moa.isin(moas)].moa.value_counts()
# Out:
# HDAC inhibitor                      25
# topoisomerase inhibitor             23
# PARP inhibitor                      18
# tubulin polymerization inhibitor    16
# JAK inhibitor                       15
# retinoid receptor agonist           14
# HSP inhibitor                       13
# Aurora kinase inhibitor             12
# ATPase inhibitor                    12
# protein synthesis inhibitor          8
# Name: moa, dtype: int64

# %% [markdown]
# # Compounds from Specs1K-v2

# %%
# Download compounds that were used to perturb cells for HIC from second batch that comes from PharmBio Lab
compounds2 = pd.read_csv('/home/jovyan/scratch-shared/erik/from_phil/SPECS1K-v2.csv', sep=',')

# %%
compounds2[0:5]
# Out:
#   Compound ID   Batch nr CUSTOMER_ID   MOLFORMULA  MOLWEIGHT  \
# 0   CBK042036  BJ1899146   K95309561     C18H18O2     266.34
# 1   CBK290570  BJ1895339   K92428153    C23H31NO7     433.51
# 2   CBK307944  BJ1895660   K82908348  C23H20N2O4S     420.49
# 3   CBK016703  BJ1894591   K82236179     C19H12O6     336.30
# 4   CBK011717  BJ1894651   K82103381   C8H8N4.HCl     196.64
#
#                       NAME_x                         VENDOR         ADD_INFO  \
# 0                 dienestrol                      TargetMol      CAS 84-17-3
# 1      MYCOPHENOLATE MOFETIL  Microsource Discovery Systems      115007-34-6
# 2               darglitazone                      Sanbio BV  CAS 141200-24-0
# 3                  DICUMAROL  Microsource Discovery Systems   66-76-2 (acid)
# 4  HYDRALAZINE HYDROCHLORIDE  Microsource Discovery Systems          86-54-4
#
#                                             SMILES_x  \
# 0              C\C=C(c1ccc(O)cc1)\C(c1ccc(O)cc1)=C\C
# 1  COc1c(C)c2COC(=O)c2c(O)c1C\C=C(/C)CCC(=O)OCCN1...
# 2  O=C(CCC1=C(C)OC(C2=CC=CC=C2)=N1)C3=CC=C(CC4SC(...
# 3          Oc1c(Cc2c(O)c3ccccc3oc2=O)c(=O)oc2ccccc12
# 4                                   NNc1nncc2ccccc12
#
#                                           IUPAC_NAME  ...          CAS  \
# 0  4-[(E,1Z)-1-ethylidene-2-(4-hydroxyphenyl)but-...  ...      84-17-3
# 1  2-morpholinoethyl (E)-6-(4-hydroxy-6-methoxy-7...  ...  128794-94-5
# 2  5-[[4-[3-(5-methyl-2-phenyl-oxazol-4-yl)propan...  ...  141200-24-0
# 3  4-hydroxy-3-[(4-hydroxy-2-oxo-chromen-3-yl)met...  ...      66-76-2
# 4                           phthalazin-1-ylhydrazine  ...     304-20-1
#
#   PUBCHEM_CID  PUBCHEM_SID PURITY_RATING PURITY_RATING_4M  \
# 0    667476.0  170465362.0             A              NaN
# 1   5281078.0  170464859.0             A              NaN
# 2     60870.0  170466177.0             A                A
# 3  54676038.0  170465275.0             F              NaN
# 4      9351.0  144212813.0             A                A
#
#                       NAME_y  \
# 0                 Dienestrol
# 1      Mycophenolate mofetil
# 2               Darglitazone
# 3                  Dicumarol
# 4  Hydralazine hydrochloride
#
#                                             SMILES_y        TOX21_ID  \
# 0              Oc1ccc(cc1)C(=C\C)/C(=C/C)c2ccc(O)cc2  Tox21_110378_1
# 1  Oc3c1C(=O)OCc1c(C)c(OC)c3C\C=C(/C)CCC(=O)OCCN2...  Tox21_111686_1
# 2  Cc3oc(nc3CCC(=O)c2ccc(CC1SC(=O)NC1=O)cc2)c4ccccc4    Tox21_113876
# 3         OC=3c4ccccc4OC(=O)C=3CC1=C(O)c2ccccc2OC1=O  Tox21_110357_1
# 4                                Cl.NNc2nncc1ccccc12    Tox21_302496
#
#                   Selected_mechanism of action (MoA)  \
# 0                          estrogen receptor agonist
# 1  dehydrogenase inhibitor|inositol monophosphata...
# 2                           PPAR receptor antagonist
# 3                                    NADPH inhibitor
# 4                                        vasodilator
#
#                                   selected_mechanism
# 0  agonists of the antioxidant response element (...
# 1  agonists of the antioxidant response element (...
# 2  agonists of the antioxidant response element (...
# 3  agonists of the antioxidant response element (...
# 4  agonists of the antioxidant response element (...
#
# [5 rows x 37 columns]

# %%
compounds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Compound ID                         999 non-null    object
#  1   Batch nr                            999 non-null    object
#  2   CUSTOMER_ID                         999 non-null    object
#  3   MOLFORMULA                          999 non-null    object
#  4   MOLWEIGHT                           999 non-null    float64
#  5   NAME_x                              995 non-null    object
#  6   VENDOR                              999 non-null    object
#  7   ADD_INFO                            875 non-null    object
#  8   SMILES_x                            999 non-null    object
#  9   IUPAC_NAME                          993 non-null    object
#  10  STEREOCHEMISTRY                     251 non-null    object
#  11  pert_iname                          925 non-null    object
#  12  clinical_phase                      888 non-null    object
#  13  moa                                 816 non-null    object
#  14  target                              587 non-null    object
#  15  disease_area                        524 non-null    object
#  16  indication                          524 non-null    object
#  17  SAMPLE_ID                           529 non-null    object
#  18  PROTOCOL_NAME                       529 non-null    object
#  19  SAMPLE_DATA_TYPE                    529 non-null    object
#  20  ASSAY_OUTCOME                       529 non-null    object
#  21  CHANNEL_OUTCOME                     497 non-null    object
#  22  AC50                                477 non-null    float64
#  23  EFFICACY                            529 non-null    float64
#  24  REPRODUCIBILITY                     529 non-null    object
#  25  CURVE_RANK                          529 non-null    float64
#  26  FLAG                                41 non-null     object
#  27  CAS                                 529 non-null    object
#  28  PUBCHEM_CID                         529 non-null    float64
#  29  PUBCHEM_SID                         529 non-null    float64
#  30  PURITY_RATING                       523 non-null    object
#  31  PURITY_RATING_4M                    306 non-null    object
#  32  NAME_y                              529 non-null    object
#  33  SMILES_y                            529 non-null    object
#  34  TOX21_ID                            529 non-null    object
#  35  Selected_mechanism of action (MoA)  816 non-null    object
#  36  selected_mechanism                  529 non-null    object
# dtypes: float64(6), object(31)
# memory usage: 288.9+ KB

# %%
compounds2.shape
# Out:
# (999, 37)

# %%
compounds2.NAME_x[:500]
# Out:
# 0                         dienestrol
# 1              MYCOPHENOLATE MOFETIL
# 2                       darglitazone
# 3                          DICUMAROL
# 4          HYDRALAZINE HYDROCHLORIDE
#                    ...
# 495    Tenofovir Disoproxil Fumarate
# 496                     ZOLMITRIPTAN
# 497               CEFMETAZOLE SODIUM
# 498                  Propentofylline
# 499           TIAPRIDE HYDROCHLORIDE
# Name: NAME_x, Length: 500, dtype: object

# %%
compounds2.NAME_y
# Out:
# 0                     Dienestrol
# 1          Mycophenolate mofetil
# 2                   Darglitazone
# 3                      Dicumarol
# 4      Hydralazine hydrochloride
#                  ...
# 994                          NaN
# 995                          NaN
# 996                          NaN
# 997                          NaN
# 998                          NaN
# Name: NAME_y, Length: 999, dtype: object

# %%
compounds2.pert_iname[:500]
# Out:
# 0                 dienestrol
# 1      mycophenolate-mofetil
# 2               darglitazone
# 3                 dicoumarol
# 4                hydralazine
#                ...
# 495     tenofovir-disoproxil
# 496             zolmitriptan
# 497              cefmetazole
# 498          propentofylline
# 499                 tiapride
# Name: pert_iname, Length: 500, dtype: object

# %%
compounds2.IUPAC_NAME[:50]
# Out:
# 0     4-[(E,1Z)-1-ethylidene-2-(4-hydroxyphenyl)but-...
# 1     2-morpholinoethyl (E)-6-(4-hydroxy-6-methoxy-7...
# 2     5-[[4-[3-(5-methyl-2-phenyl-oxazol-4-yl)propan...
# 3     4-hydroxy-3-[(4-hydroxy-2-oxo-chromen-3-yl)met...
# 4                              phthalazin-1-ylhydrazine
# 5             [(E)-(5-nitro-2-furyl)methyleneamino]urea
# 6     1-[(2,4-Dichlorophenyl)methyl]-1H-indazole-3-c...
# 7     1-[(E)-(5-nitro-2-furyl)methyleneamino]imidazo...
# 8                                  3,5-dinitrobenzamide
# 9                 3-[(E)-phenylazo]pyridine-2,6-diamine
# 10    5-fluoro-1-[(4R,5R)-4-hydroxy-5-(hydroxymethyl...
# 11    (E)-N-[(4-hydroxy-3-methoxy-phenyl)methyl]-8-m...
# 12    2-[3-[4-(3-chlorophenyl)piperazin-1-yl]propyl]...
# 13    N-(4-Chlorophenyl)-4-(4-pyridinylmethyl)-1-pht...
# 14           4-[1-ethyl-2-(4-hydroxyphenyl)butyl]phenol
# 15    4-[3-(difluoromethyl)-5-(3-fluoro-4-methoxy-ph...
# 16                    4-(dichlorosulfamoyl)benzoic acid
# 17    3-[(3,5-Dimethyl-1H-pyrrol-2-yl)methylene]-1,3...
# 18    1-cyclopropyl-7-[(3R,5S)-3,5-dimethylpiperazin...
# 19    (2E,6E)-2,6-bis[(4-hydroxy-3-methoxy-phenyl)me...
# 20    3,4-Dideoxy-4-[[2-hydroxy-1-(hydroxymethyl)eth...
# 21    (8S,10S)-10-{[(2R,4S,5R,6S)-4-amino-5-hydroxy-...
# 22    (1S,3Z)-3-[(2E)-2-[(3aS,7aR)-7a-methyl-1-[(E,1...
# 23    1-[(3S,10R,13S,17S)-3-hydroxy-10,13-dimethyl-2...
# 24    (2E)-[(4R)-4-(2,4-dichlorophenyl)-1,3-dithiola...
# 25    5,5-dimethyl-3-[4-nitro-3-(trifluoromethyl)phe...
# 26            2-(3-chloro-2-methyl-anilino)benzoic acid
# 27    (10R,13S,17S)-17-hydroxy-10,13-dimethyl-1,2,6,...
# 28    2-methyl-N-[4-nitro-3-(trifluoromethyl)phenyl]...
# 29    7-phenyl-7-(2,4,5-trimethyl-3,6-dioxo-cyclohex...
# 30    [2-(dimethylamino)-2-phenyl-butyl] 3,4,5-trime...
# 31    2-[3-[4-(4-Fluorophenyl)-1-piperazinyl]propyl]...
# 32                   1,8-dihydroxyanthracene-9,10-dione
# 33    [2-({(E)-amino[(diaminomethylene)amino]methyli...
# 34    3-[(E)-(5-nitro-2-furyl)methyleneamino]oxazoli...
# 35    N-[2-[4-(cyclohexylcarbamoylsulfamoyl)phenyl]e...
# 36                                    2-hexoxybenzamide
# 37    3-bromo-1-[4-(3-bromopropanoyl)piperazin-1-yl]...
# 38        1-[(2-chlorophenyl)-diphenyl-methyl]imidazole
# 39             6-ethoxy-1,3-benzothiazole-2-sulfonamide
# 40    [(1S,3R,7S,8S,8aR)-8-[2-[(2R,4R)-4-hydroxy-6-o...
# 41    (2E,4E,6E,8E)-3,7-dimethyl-9-(2,6,6-trimethylc...
# 42    5-amino-1-[2,6-dichloro-4-(trifluoromethyl)phe...
# 43    1-[(4-chlorophenyl)-phenyl-methyl]-4-(m-tolylm...
# 44    1-[4-[4-[[(2R)-2-(2,4-dichlorophenyl)-2-(imida...
# 45    O5-ethyl O3-methyl 4-(2,3-dichlorophenyl)-2,6-...
# 46    3-[4-[3-(3,4,5-trimethoxybenzoyl)oxypropyl]-1,...
# 47                          pentacyano(nitroso)iron(2-)
# 48              4-[3-(4-butoxyphenoxy)propyl]morpholine
# 49    4-[(E)-1-ethyl-2-(4-hydroxyphenyl)but-1-enyl]p...
# Name: IUPAC_NAME, dtype: object

# %%
compounds2.NAME_y[:100]
# Out:
# 0                        Dienestrol
# 1             Mycophenolate mofetil
# 2                      Darglitazone
# 3                         Dicumarol
# 4         Hydralazine hydrochloride
#                   ...
# 95                     Lubiprostone
# 96                Megestrol acetate
# 97                      Trepibutone
# 98    Trifluoperazine hydrochloride
# 99                  Monensin sodium
# Name: NAME_y, Length: 100, dtype: object

# %% [markdown]
# compounds2.IUPAC_NAME[:50]# Combining Specs1K-v2 and Specs935compounds2.pert_iname[:50]

# %%
# checking to see the different names of the columns. Some differences occur which could be fixed (notice x with SMILES for example), but does not effect following
for col1,col2 in zip(compounds.columns[1:], compounds2.columns):
    print((col1,col2))
# Out:
# ('Compound ID', 'Compound ID')
# ('Batch nr', 'Batch nr')
# ('CUSTOMER_ID', 'CUSTOMER_ID')
# ('MOLFORMULA', 'MOLFORMULA')
# ('MOLWEIGHT', 'MOLWEIGHT')
# ('NAME', 'NAME_x')
# ('VENDOR', 'VENDOR')
# ('ADD_INFO', 'ADD_INFO')
# ('SMILES', 'SMILES_x')
# ('IUPAC_NAME', 'IUPAC_NAME')
# ('STEREOCHEMISTRY', 'STEREOCHEMISTRY')
# ('pert_iname', 'pert_iname')
# ('clinical_phase', 'clinical_phase')
# ('moa', 'moa')
# ('target', 'target')
# ('disease_area', 'disease_area')
# ('indication', 'indication')
# ('SAMPLE_ID', 'SAMPLE_ID')
# ('PROTOCOL_NAME', 'PROTOCOL_NAME')
# ('SAMPLE_DATA_TYPE', 'SAMPLE_DATA_TYPE')
# ('ASSAY_OUTCOME', 'ASSAY_OUTCOME')
# ('CHANNEL_OUTCOME', 'CHANNEL_OUTCOME')
# ('AC50', 'AC50')
# ('EFFICACY', 'EFFICACY')
# ('REPRODUCIBILITY', 'REPRODUCIBILITY')
# ('CURVE_RANK', 'CURVE_RANK')
# ('FLAG', 'FLAG')
# ('CAS', 'CAS')
# ('PUBCHEM_CID', 'PUBCHEM_CID')
# ('PUBCHEM_SID', 'PUBCHEM_SID')
# ('PURITY_RATING', 'PURITY_RATING')
# ('PURITY_RATING_4M', 'PURITY_RATING_4M')
# ('TOX21_ID', 'NAME_y')
# ('DILIST_ID', 'SMILES_y')
# ('DILIst Classification', 'TOX21_ID')
# ('Routs of Administration', 'Selected_mechanism of action (MoA)')
# ('selected_mechanism of action (MoA)', 'selected_mechanism')

# %%
a = compounds[["CUSTOMER_ID", "Batch nr", "Compound ID", "moa", "NAME", "pert_iname", "SMILES"]]
b = compounds2[["CUSTOMER_ID", "Batch nr", "Compound ID", "moa", "NAME_x","NAME_y", "pert_iname", "SMILES_x", "SMILES_y"]]

# %%
# Concatenating both specs into a large dataframe
frames = [a, b]
compounds1_2 = pd.concat(frames)
compounds1_2.shape
# Out:
# (1934, 11)

# %% [markdown]
# Shape looks reasonable. Compounds1 (935) + Compounds2 (999) = 1934

# %% [markdown]
# ## Looking at Proteomics Data

# %%
# Download compounds that were used to perturb cells for HIC from first batch that comes from PharmBio Lab
proteomics = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/06_Proteomics_Models/bro.csv', sep=';')

# %%
proteomics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875 entries, 0 to 874
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Compound Name            875 non-null    object
#  1   Primary Target           875 non-null    object
#  2   Secondary Target         363 non-null    object
#  3   SMILES                   875 non-null    object
#  4   MW                       875 non-null    object
#  5   Formula                  875 non-null    object
#  6   Screening Concentration  875 non-null    object
# dtypes: object(7)
# memory usage: 48.0+ KB

# %%
proteomics[:50]
# Out:
#            Compound Name Primary Target  \
# 0              SR 142948          NTSR1
# 1              UK 356618           MMP3
# 2                 JW 480          NCEH1
# 3                 ML-265            PKM
# 4            PF-04418948         PTGER2
# 5             Ezatiostat          GSTP1
# 6             Nitisinone            HPD
# 7    4,4'-Dichlorobenzil           CES1
# 8       Pentadecanoyl EA          GPR55
# 9              Ascomycin         FKBP1A
# 10             SSR 69071          ELANE
# 11               UPF 648            KMO
# 12            Fumagillin         METAP2
# 13                GSK343           EZH2
# 14           Torcetrapib           CETP
# 15              ONX 0914          PSMB8
# 16             Balicatib           CTSK
# 17             alvimopan          OPRM1
# 18             BCATc-In2          BCAT1
# 19              BACE1_In          BACE1
# 20           Tiplaxtinin       SERPINE1
# 21  Trihydroxyisoflavone         PFKFB3
# 22               GSK4112          NR1D1
# 23                  EIPA         SLC9A1
# 24               MLN4924           NAE1
# 25           Blonanserin     DRD2;HTR2A
# 26                DY 131          ESRRG
# 27           LOMEGUATRIB           MGMT
# 28    HMB-Val-Ser-Leu-VE          KLK11
# 29            Cetrorelix          GNRHR
# 30            SCH 530348            F2R
# 31           PF 04447943          PDE9A
# 32               PF-8380          ENPP2
# 33                   ACA          TRPM2
# 34                4EGI-1          EIF4E
# 35       Undecanoic acid          AGTR2
# 36          kb NB 142-70          PRKD1
# 37              LPA2 An1          LPAR2
# 38            Sildenafil          PDE5A
# 39              CGP77675            SRC
# 40            PF 4800567         CSNK1E
# 41                  AK 7          SIRT2
# 42           CID-2745687          GPR35
# 43            GSK2578215          LRRK2
# 44            Ticagrelor         P2RY12
# 45         Cytosporone B          NR4A1
# 46          Vidofludimus          DHODH
# 47          AZD1152-HQPA          AURKB
# 48             BMS309403          FABP4
# 49               XCT 790          ESRRA
#
#                                      Secondary Target  \
# 0                                               NTSR2
# 1                                          MMP13;MMP9
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                     CES5A;CES3;CES2
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                               CTSL
# 17                                        OPRD1;OPRK1
# 18                                                NaN
# 19                                          BACE2;APP
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                        PLAU;SLC9A5
# 24                                                NaN
# 25                                        HTR2C;HTR2B
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                        TRPC6;TRPM8
# 34                                                NaN
# 35                                       ADRA1B;AGTR1
# 36                                                NaN
# 37                                                NaN
# 38  ENPP6;PDE6H;PDE6B;PDE6D;PDE6G;PDE6C;PDE6A;ADOR...
# 39                                       LCK;KDR;EGFR
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47    AURKC;KIT;FLT3;PDGFRA;PDGFRB;RET;LCK;EGFR;AURKA
# 48   FABP3;FABP12;FABP9;FABP7;FABP1;FABP2;FABP6;FABP5
# 49                                                NaN
#
#                                                SMILES       MW  \
# 0   COc1cccc(c1c1cc(nn1c1ccc(cc1C(C)C)C(=O)N(CCCN(...   685,38
# 1   ONC(=O)C[C@H](C(=O)N[C@@H](C(C)(C)C)C(=O)N[C@@...   557,32
# 2              O=C(Oc1ccccc1C(C)C)NCCc1ccc2c(c1)cccc2   333,17
# 3       Nc1cccc(c1)Cn1ncc2c(c1=O)n(C)c1c2sc(c1)S(=O)C   372,07
# 4   COc1ccc2c(c1)ccc(c2)OCC1(CN(C1)C(=O)c1ccc(cc1)...   409,13
# 5   CCOC(=O)[C@H](CCC(=O)N[C@H](C(=O)N[C@H](c1cccc...   529,22
# 6   O=C1CCCC(=O)C1C(=O)c1ccc(cc1[N+](=O)[O-])C(F)(F)F   329,05
# 7                  O=C(C(=O)c1ccc(cc1)Cl)c1ccc(cc1)Cl   277,99
# 8                             CCCCCCCCCCCCCCC(=O)NCCO   285,27
# 9   CC[C@@H]1/C=C(\C)/C[C@H](C)C[C@H](OC)[C@H]2O[C...   791,48
# 10  COc1cc(C(C)C)c2c(c1)S(=O)(=O)N(C2=O)COc1cc(=O)...    556,2
# 11          OC(=O)[C@H]1C[C@@H]1C(=O)c1ccc(c(c1)Cl)Cl   257,98
# 12  CO[C@@H]1[C@@H](CC[C@@]2([C@H]1[C@@]1(C)O[C@@H...   458,23
# 13  CCCc1cc(C)[nH]c(=O)c1CNC(=O)c1cc(cc2c1cnn2C(C)...   541,32
# 14  CCOC(=O)N1[C@H](CC)C[C@@H](c2c1ccc(c2)C(F)(F)F...   600,17
# 15  COc1ccc(cc1)C[C@@H](C(=O)N[C@H](C(=O)[C@@]1(C)...   580,29
# 16  CCCN1CCN(CC1)c1ccc(cc1)C(=O)NC1(CCCCC1)C(=O)NCC#N   411,26
# 17  OC(=O)CNC(=O)[C@@H](Cc1ccccc1)CN1CC[C@@]([C@H]...   424,24
# 18  Clc1ccc2c(c1)cc(o2)C(=O)NNS(=O)(=O)c1ccccc1C(F...      418
# 19  O[C@@H]([C@@H](NC(=O)c1cc(cc(c1)N(S(=O)(=O)C)C...   578,26
# 20  OC(=O)C(=O)c1cn(c2c1cc(cc2)c1ccc(cc1)OC(F)(F)F...    439,1
# 21                  Oc1ccc(cc1)c1coc2c(c1=O)ccc(c2O)O   270,05
# 22  O=C(OC(C)(C)C)CN(Cc1ccc(s1)[N+](=O)[O-])Cc1ccc...   396,09
# 23              CCN(c1nc(N)c(nc1Cl)C(=O)NC(=N)N)C(C)C   299,13
# 24  O[C@H]1C[C@@H](C[C@H]1COS(=O)(=O)N)n1ccc2c1ncn...   443,16
# 25          CCN1CCN(CC1)c1nc2CCCCCCc2c(c1)c1ccc(cc1)F   367,24
# 26            CCN(c1ccc(cc1)/C=N/NC(=O)c1ccc(cc1)O)CC   311,16
# 27                   Brc1csc(c1)COc1nc(N)nc2c1nc[nH]2   324,96
# 28  CCOC(=O)/C=C/[C@@H](NC(=O)[C@@H](NC(=O)[C@H](C...   505,28
# 29  OC[C@@H](C(=O)N[C@H](C(=O)N[C@@H](C(=O)N[C@H](...  1429,67
# 30  CCOC(=O)N[C@@H]1CC[C@@H]2[C@@H](C1)C[C@@H]1[C@...   492,24
# 31  C[C@@H]1CN(C[C@H]1c1[nH]c(=O)c2c(n1)n(nc2)C1CC...   395,21
# 32  Clc1cc(COC(=O)N2CCN(CC2)CCC(=O)c2ccc3c(c2)oc(=...   477,09
# 33           CCCCCc1ccc(cc1)/C=C/C(=O)Nc1ccccc1C(=O)O   337,17
# 34  OC(=O)/C(=N/Nc1scc(n1)c1ccc(c(c1)Cl)Cl)/Cc1ccc...      450
# 35                                   CCCCCCCCCCC(=O)O   186,16
# 36                          Oc1cc2c3SCCNC(=O)c3sc2cc1   251,01
# 37  C[C@H](Nc1ncnc2c1scc2C)CN1CCN(CC1)S(=O)(=O)c1c...   499,07
# 38  CCCc1nn(c2c1[nH]c(nc2=O)c1cc(ccc1OCC)S(=O)(=O)...    474,2
# 39  COc1cccc(c1)c1cn(c2c1c(N)ncn2)c1ccc(cc1)CCN1CC...   443,23
# 40           Clc1cccc(c1)OCc1nn(c2c1c(N)ncn2)C1CCOCC1   359,12
# 41     Brc1cccc(c1)NC(=O)c1cccc(c1)S(=O)(=O)N1CCCCCC1   436,05
# 42   COC(=O)c1cnn(c1/C=N/NC(=S)NC(C)(C)C)c1ccc(cc1F)F   395,12
# 43    Fc1nccc(c1)c1ccc(c(c1)C(=O)Nc1cccnc1)OCc1ccccc1   399,14
# 44  CCCSc1nc(N[C@@H]2C[C@H]2c2ccc(c(c2)F)F)c2c(n1)...   522,19
# 45                CCCCCCCC(=O)c1c(O)cc(cc1CC(=O)OCC)O   322,18
# 46    COc1cccc(c1)c1ccc(c(c1)F)NC(=O)C1=C(CCC1)C(=O)O   355,12
# 47  OCCN(CCCOc1ccc2c(c1)ncnc2Nc1n[nH]c(c1)CC(=O)Nc...   507,24
# 48  CCc1c(c2ccccc2)c(nn1c1ccccc1c1cccc(c1)OCC(=O)O...   474,19
# 49  N#C/C(=C\c1ccc(c(c1)OC)OCc1ccc(cc1C(F)(F)F)C(F...   596,06
#
#             Formula Screening Concentration
# 0        C39H51N5O6                    10uM
# 1        C34H43N3O4                    10uM
# 2         C22H23NO2                    10uM
# 3      C17H16N4O2S2                    10uM
# 4        C23H20FNO5                    10uM
# 5       C27H35N3O6S                    10uM
# 6       C14H10F3NO5                    10uM
# 7        C14H8Cl2O2                    10uM
# 8         C17H35NO2                    10uM
# 9        C43H69NO12                    10uM
# 10      C27H32N4O7S                    10uM
# 11       C11H8Cl2O3                    10uM
# 12         C26H34O7                    10uM
# 13       C31H39N7O2                    10uM
# 14     C26H25F9N2O4                    10uM
# 15       C31H40N4O7                    10uM
# 16       C23H33N5O2                    10uM
# 17       C25H32N2O4                    10uM
# 18  C16H10ClF3N2O4S                    10uM
# 19      C31H38N4O5S                    10uM
# 20      C24H16F3NO4                    10uM
# 21         C15H10O5                    10uM
# 22    C18H21ClN2O4S                    10uM
# 23      C11H18ClN7O                    10uM
# 24      C21H25N5O4S                    10uM
# 25        C23H30FN3                    10uM
# 26       C18H21N3O2                    10uM
# 27      C10H8BrN5OS                    10uM
# 28       C26H39N3O7                    10uM
# 29   C70H92ClN17O14                    10uM
# 30      C29H33FN2O4                    10uM
# 31       C20H25N7O2                    10uM
# 32    C22H21Cl2N3O5                    10uM
# 33        C21H23NO3                    10uM
# 34   C18H12Cl2N4O4S                    10uM
# 35         C11H22O2                    10uM
# 36       C11H9NO2S2                    10uM
# 37  C20H23Cl2N5O2S2                    10uM
# 38      C22H30N6O4S                    10uM
# 39       C26H29N5O2                    10uM
# 40     C17H18ClN5O2                    10uM
# 41    C19H21BrN2O3S                    10uM
# 42    C17H19F2N5O2S                    10uM
# 43      C24H18FN3O2                    10uM
# 44    C23H28F2N6O4S                    10uM
# 45         C18H26O5                    10uM
# 46       C20H18FNO4                    10uM
# 47      C26H30FN7O3                    10uM
# 48       C31H26N2O3                    10uM
# 49    C23H13F9N4O3S                    10uM

# %%
proteomics_SPECS1 = proteomics[proteomics["SMILES"].isin(compounds1_2["SMILES_x"])|
                               proteomics["SMILES"].isin(compounds1_2["SMILES_y"])].reset_index(drop=True)

# %%
# If the ID in compounds is in the list of clue compounds, include it in a new data frame. 
proteomics_SPECS = proteomics[proteomics["Compound Name"].isin(compounds1_2["NAME_x"])|
                              proteomics["Compound Name"].isin(compounds1_2["NAME_y"])|
                              proteomics["Compound Name"].isin(compounds1_2["pert_iname"])].reset_index(drop=True)

# %%
proteomics_SPECS1
# Out:
#   Compound Name Primary Target Secondary Target  \
# 0         PX-12         TXNRD1              NaN
# 1   Seratrodast         TBXA2R              NaN
# 2  Testolactone        CYP19A1              NaN
#
#                                               SMILES      MW    Formula  \
# 0                                  CCC(SSC1=NC=CN1)C  188,04  C7H12N2S2
# 1  CC(C1=O)=C(C(C(C)=C1C)=O)C(C2=CC=CC=C2)CCCCCC(...  354,18   C22H26O4
# 2  O=C1CC[C@]2([H])[C@@](CC[C@]3([H])[C@@]4(C)C=C...  300,17   C19H24O3
#
#   Screening Concentration
# 0                    10uM
# 1                    10uM
# 2                    10uM

# %% [markdown]
# Using SMILE Strings does not work (we get three hits instead of 50). However, those hits generate unique compounds not found in the 50, which gives me some hope that more compounds could be overlapping the SPECS 1 and 2.

# %%
proteomics_SPECS.shape
# Out:
# (50, 8)

# %%
P100 = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/06_Proteomics_Models/GSE101406_Broad_LINCS_P100_inst_info.txt', delimiter = "\t")

# %%
P100['pert_id'] =  P100['pert_id'].map(lambda x: x.lstrip('BRD-'))

# %%
P100 = P100.drop_duplicates(subset=['pert_id'])

# %%
P100.shape
# Out:
# (90, 12)

# %%
P100
# Out:
#                inst_id cell_id det_plate det_well     lsm_id  pert_dose  \
# 0     PA5-11373-001A01    A375    P-0022       A1  LSM-36361        0.0
# 54    PA5-11373-004A04    A375    P-0022       A4   LSM-2135        3.0
# 72    PA5-11373-007A07    A375    P-0022       A7  LSM-42755       10.0
# 90    PA5-11373-010A10    A375    P-0022      A10   LSM-1141        1.0
# 106   PA5-11373-013B01    A375    P-0022       B1   LSM-6348        5.0
# ...                ...     ...       ...      ...        ...        ...
# 1624   PA5-EC63-076G04    A375    P-0017       G4   LSM-4571       10.0
# 1642   PA5-EC63-079G07    A375    P-0017       G7   LSM-6338        1.0
# 1660   PA5-EC63-085H01    A375    P-0017       H1  LSM-36364        3.0
# 1678   PA5-EC63-091H07    A375    P-0017       H7  LSM-36369       12.0
# 1696   PA5-EC63-094H10    A375    P-0017      H10   LSM-2597       10.0
#
#      pert_dose_unit    pert_id  pert_time pert_time_unit    pert_iname  \
# 0                uM  K08970894          3              h          DMSO
# 54               uM  K64634304          3              h     tretinoin
# 72               uM  A81177136          3              h         KN-62
# 90               uM  K87737963          3              h        CYT387
# 106              uM  K37798499          3              h     etoposide
# ...             ...        ...        ...            ...           ...
# 1624             uM  K26818574          3              h     BIX-01294
# 1642             uM  K83189926          3              h      UNC-1215
# 1660             uM  A65730376          3              h     epz004777
# 1678             uM  K90860366          3              h  1271738-62-5
# 1696             uM  K27305650          3              h     LY-294002
#
#         pert_type
# 0     ctl_vehicle
# 54         trt_cp
# 72         trt_cp
# 90         trt_cp
# 106        trt_cp
# ...           ...
# 1624       trt_cp
# 1642       trt_cp
# 1660       trt_cp
# 1678       trt_cp
# 1696       trt_cp
#
# [90 rows x 12 columns]

# %%
GCP = pd.read_csv('/home/jovyan/Tomics-CP-Chem-MoA/06_Proteomics_Models/GSE101406_Broad_LINCS_GCP_inst_info 2.txt', delimiter = "\t")

# %%
GCP['pert_id'] =  GCP['pert_id'].map(lambda x: x.lstrip('BRD-'))

# %%
GCP.shape
# Out:
# (1721, 12)

# %%
GCP = GCP.drop_duplicates(subset=['pert_id'])

# %%
GCP.shape
# Out:
# (90, 12)

# %%
GCP
# Out:
#                inst_id cell_id det_plate det_well     lsm_id  pert_dose  \
# 0     GA5-11373-001A01    A375    G-0022       A1  LSM-36361       0.00
# 54    GA5-11373-004A04    A375    G-0022       A4   LSM-2135       3.00
# 72    GA5-11373-007A07    A375    G-0022       A7  LSM-42755      10.00
# 90    GA5-11373-010A10    A375    G-0022      A10   LSM-1141       1.00
# 108   GA5-11373-013B01    A375    G-0022       B1   LSM-6348       5.00
# ...                ...     ...       ...      ...        ...        ...
# 1634  GA5-421DF-079G07    A375    G-0028       G7  LSM-42768       2.50
# 1652  GA5-421DF-085H01    A375    G-0028       H1   LSM-3347       0.75
# 1670  GA5-421DF-091H07    A375    G-0028       H7   LSM-4256       0.25
# 1688  GA5-421DF-094H10    A375    G-0028      H10   LSM-5975      10.00
# 1706  GA9-2C187-091H07    A549    G-0025       H7  LSM-42759       1.00
#
#      pert_dose_unit    pert_id  pert_time pert_time_unit       pert_iname  \
# 0                uM  K08970894         24              h             DMSO
# 54               uM  K64634304         24              h        tretinoin
# 72               uM  A81177136         24              h            KN-62
# 90               uM  K87737963         24              h           CYT387
# 108              uM  K37798499         24              h        etoposide
# ...             ...        ...        ...            ...              ...
# 1634             uM  K25412176         24              h      GSK-2110183
# 1652             uM  A11170096         24              h      pravastatin
# 1670             uM  K54997624         24              h        alpelisib
# 1688             uM  K93023739         24              h  IKK-inhibitor-X
# 1706             uM  A13254067         24              h     okadaic acid
#
#         pert_type
# 0     ctl_vehicle
# 54         trt_cp
# 72         trt_cp
# 90         trt_cp
# 108        trt_cp
# ...           ...
# 1634       trt_cp
# 1652       trt_cp
# 1670       trt_cp
# 1688       trt_cp
# 1706       trt_cp
#
# [90 rows x 12 columns]

# %%
combined_GCP = compounds1_2[compounds1_2.CUSTOMER_ID.isin(GCP["pert_id"])].reset_index(drop=True)

# %%
combined_GCP
# Out:
#    CUSTOMER_ID   Batch nr Compound ID  \
# 0    K80738081  BJ1897518   CBK041257
# 1    K37798499  BJ1897223   CBK041182
# 2    K56343971  BJ1897084   CBK277976
# 3    K81418486  BJ1898152   CBK201016
# 4    K17743125  BJ1898165   CBK277957
# 5    K52313696  BJ1898688   CBK277961
# 6    K61688984  BJ1898934   CBK303885
# 7    K53972329  BJ1898256   CBK277968
# 8    K87737963  BJ1898441   CBK278067
# 9    K79254416  BJ1895936   CBK201329
# 10   K26818574  BJ1899036   CBK289749
# 11   K57754230  BJ1898859   CBK303977
# 12   K74236984  BJ1897068   CBK308689
# 13   K87465484  BJ1897249   CBK308823
# 14   K27305650  BJ1894333   CBK041160
# 15   K87124298  BJ1898582   CBK277965
# 16   K12184916  BJ1898137   CBK278012
# 17   A34255068  BJ1895493   CBK011603
# 18   K35960502  BJ1895172   CBK016247
#
#                                                   moa  \
# 0            cytochrome P450 inhibitor|SIRT activator
# 1                             topoisomerase inhibitor
# 2                                       RAF inhibitor
# 3                                      HDAC inhibitor
# 4                                      HDAC inhibitor
# 5                                      HDAC inhibitor
# 6                                      HDAC inhibitor
# 7                                       JAK inhibitor
# 8                                       JAK inhibitor
# 9                     DNA methyltransferase inhibitor
# 10         histone lysine methyltransferase inhibitor
# 11         histone lysine methyltransferase inhibitor
# 12         histone lysine methyltransferase inhibitor
# 13         histone lysine methyltransferase inhibitor
# 14  DNA dependent protein kinase inhibitor|mTOR in...
# 15                                     mTOR inhibitor
# 16                      mTOR inhibitor|PI3K inhibitor
# 17                        phosphodiesterase inhibitor
# 18           DNA replication inhibitor|STAT inhibitor
#
#                                NAME    pert_iname       NAME_x       NAME_y
# 0                       Resveratrol   resveratrol          NaN          NaN
# 1                         Etoposide     etoposide          NaN          NaN
# 2                       Vemurafenib   vemurafenib          NaN          NaN
# 3         Vorinostat (SAHA, MK0683)    vorinostat          NaN          NaN
# 4               Belinostat (PXD101)    belinostat          NaN          NaN
# 5              CI994 (Tacedinaline)  tacedinaline          NaN          NaN
# 6                           RGFP966       RGFP966          NaN          NaN
# 7          Ruxolitinib (INCB018424)   ruxolitinib          NaN          NaN
# 8              Momelotinib (CYT387)        cyt387          NaN          NaN
# 9                        decitabine    decitabine          NaN          NaN
# 10                        BIX 01294     BIX-01294          NaN          NaN
# 11                        EPZ005687     EPZ005687          NaN          NaN
# 12                          UNC0321       UNC0321          NaN          NaN
# 13                          UNC0646       UNC0646          NaN          NaN
# 14                         LY294002      LY294002          NaN          NaN
# 15                          OSI-027       OSI-027          NaN          NaN
# 16  Dactolisib (BEZ235, NVP-BEZ235)    NVP-BEZ235          NaN          NaN
# 17                         ROLIPRAM      rolipram          NaN          NaN
# 18                              NaN   niclosamide  NICLOSAMIDE  Niclosamide

# %%
combined_P100 = compounds1_2[compounds1_2.CUSTOMER_ID.isin(P100["pert_id"])].reset_index(drop=True)

# %%
combined_P100
# Out:
#    CUSTOMER_ID   Batch nr Compound ID  \
# 0    K80738081  BJ1897518   CBK041257
# 1    K37798499  BJ1897223   CBK041182
# 2    K56343971  BJ1897084   CBK277976
# 3    K81418486  BJ1898152   CBK201016
# 4    K17743125  BJ1898165   CBK277957
# 5    K52313696  BJ1898688   CBK277961
# 6    K61688984  BJ1898934   CBK303885
# 7    K53972329  BJ1898256   CBK277968
# 8    K87737963  BJ1898441   CBK278067
# 9    K79254416  BJ1895936   CBK201329
# 10   K26818574  BJ1899036   CBK289749
# 11   K57754230  BJ1898859   CBK303977
# 12   K74236984  BJ1897068   CBK308689
# 13   K87465484  BJ1897249   CBK308823
# 14   K27305650  BJ1894333   CBK041160
# 15   K87124298  BJ1898582   CBK277965
# 16   K12184916  BJ1898137   CBK278012
# 17   A34255068  BJ1895493   CBK011603
# 18   K35960502  BJ1895172   CBK016247
#
#                                                   moa  \
# 0            cytochrome P450 inhibitor|SIRT activator
# 1                             topoisomerase inhibitor
# 2                                       RAF inhibitor
# 3                                      HDAC inhibitor
# 4                                      HDAC inhibitor
# 5                                      HDAC inhibitor
# 6                                      HDAC inhibitor
# 7                                       JAK inhibitor
# 8                                       JAK inhibitor
# 9                     DNA methyltransferase inhibitor
# 10         histone lysine methyltransferase inhibitor
# 11         histone lysine methyltransferase inhibitor
# 12         histone lysine methyltransferase inhibitor
# 13         histone lysine methyltransferase inhibitor
# 14  DNA dependent protein kinase inhibitor|mTOR in...
# 15                                     mTOR inhibitor
# 16                      mTOR inhibitor|PI3K inhibitor
# 17                        phosphodiesterase inhibitor
# 18           DNA replication inhibitor|STAT inhibitor
#
#                                NAME    pert_iname       NAME_x       NAME_y
# 0                       Resveratrol   resveratrol          NaN          NaN
# 1                         Etoposide     etoposide          NaN          NaN
# 2                       Vemurafenib   vemurafenib          NaN          NaN
# 3         Vorinostat (SAHA, MK0683)    vorinostat          NaN          NaN
# 4               Belinostat (PXD101)    belinostat          NaN          NaN
# 5              CI994 (Tacedinaline)  tacedinaline          NaN          NaN
# 6                           RGFP966       RGFP966          NaN          NaN
# 7          Ruxolitinib (INCB018424)   ruxolitinib          NaN          NaN
# 8              Momelotinib (CYT387)        cyt387          NaN          NaN
# 9                        decitabine    decitabine          NaN          NaN
# 10                        BIX 01294     BIX-01294          NaN          NaN
# 11                        EPZ005687     EPZ005687          NaN          NaN
# 12                          UNC0321       UNC0321          NaN          NaN
# 13                          UNC0646       UNC0646          NaN          NaN
# 14                         LY294002      LY294002          NaN          NaN
# 15                          OSI-027       OSI-027          NaN          NaN
# 16  Dactolisib (BEZ235, NVP-BEZ235)    NVP-BEZ235          NaN          NaN
# 17                         ROLIPRAM      rolipram          NaN          NaN
# 18                              NaN   niclosamide  NICLOSAMIDE  Niclosamide
