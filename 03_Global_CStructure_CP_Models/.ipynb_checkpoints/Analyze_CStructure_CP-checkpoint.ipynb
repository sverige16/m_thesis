# %% [markdown]
# ## PREP

# %%
import torch
import glob
from IPython import display
import numpy as np
import seaborn as sns
import os

# %%
# Automatic Loading Based on Latest File Edited
CP_latest = True
CStructure_latest = True
feat_ext = True
fine_tune = True

# %%
def newest(path):
    '''Got from the internet
    Take the latest file added to the directory within a directory and returns the path
    path: path to directory (str)
    '''
    files = os.listdir(path)
    paths = [os.path.join(path, basename) for basename in files]
    return max(paths, key=os.path.getctime)

# %%
def specific_files(path):
    '''Selecting specific models based on the name in the file and then selecting the latest one'''
    files = glob.glob(path)
    paths = [os.path.join(path, basename) for basename in files]
    return max(paths, key=os.path.getctime)

# %%
def display_loss(path, automatic):
    if automatic == True:
        last_edited_file = specific_files(path)
        print(last_edited_file)
        img = display.Image(filename = str(last_edited_file))
    else:
        x = input('Input path Loss: ')
        img = display.Image(x)
    return img

def display_acc(path, automatic):
    if automatic == True:
        last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
        print(last_edited_file)
        img = display.Image(last_edited_file)
    else:
        x = input('Input path for Accuracy: ')
        img = display.Image(x)
    return img

def load_state(path,automatic):
    if automatic == True:
        last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_models')
        print(last_edited_file)
        state = torch.load(last_edited_file)
    else:
        x = input('Input path for CP model: ')
        state = torch.load(x)
    return state

def classif_report(path, automatic):
    if automatic == True:
        last_edited_file = newest(path)
        print(last_edited_file)
        with open(last_edited_file, 'r') as f2:
            data = f2.read()
            print(data)
    else:
        x = input('Input path for Classification Report: ')
        with open(x, 'r') as f2:
            data = f2.read()
            print(data)

def conf_matrix(path, automatic):
    if automatic == True:
        last_edited_file = newest(path)
        print(last_edited_file)
        cf_matrix = np.load(last_edited_file)
    else:
        x = input('Input path for confusion matrix: ')
        cf_matrix = np.load(x)
    #cf_matrix = np.load('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices/12_12_2022-13:19:41_confusion_matrix.npy')
    cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
    '''group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']'''
    #group_counts = ['{0:0.0f}'.format(value) for value in
                #cf_matrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
    labels = [f'{v1}\n' for v1 in group_percentages]
    labels = np.asarray(labels).reshape(10, 10)
    print(sns.heatmap(cf_matrix, annot = True, fmt='.2f').set(title = 'Normalized Chemical Structure Confusion Matrix'))

# %% [markdown]
# # CP MODEL

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/loss*'
display_loss(path, CP_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/loss_train_val.png

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/acc*'
display_acc(path, CP_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/acc_train_val.png

# %%
path= '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_models'
state = load_state(path, CP_latest)
b = state['valid_loss']
b
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_models/CP_least_loss_model
# 12.440389528870583

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_classification_reports'
classif_report(path, CP_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_classification_reports/14_12_2022-11:31:00_classif_report.txt
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.88      0.93         8
#            2       1.00      1.00      1.00        11
#            3       1.00      1.00      1.00         6
#            4       0.94      1.00      0.97        16
#            5       1.00      1.00      1.00        18
#            6       1.00      1.00      1.00         6
#            7       1.00      1.00      1.00        10
#            8       1.00      1.00      1.00         9
#            9       1.00      1.00      1.00         4
#
#     accuracy                           0.99        98
#    macro avg       0.99      0.99      0.99        98
# weighted avg       0.99      0.99      0.99        98

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_confusion_matrices'
conf_matrix(path, CP_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_confusion_matrices/14_12_2022-11:31:00_confusion_matrix.npy
# [Text(0.5, 1.0, 'Normalized Chemical Structure Confusion Matrix')]

# %% [markdown]
# # CStructure

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/loss*'
display_loss(path, CStructure_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/loss_train_val_13_12_2022-12:30:50.png

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/acc*'
display_acc(path, CP_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/acc_train_val_13_12_2022-12:30:50.png

# %%
path= '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_models'
state = load_state(path, CP_latest)
b = state['valid_loss']
b
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_models/CP_least_loss_model
# 12.440389528870583

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_classification_reports'
classif_report(path, CStructure_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_classification_reports/13_12_2022-12:30:50_classif_report.txt
#               precision    recall  f1-score   support
#
#            0       0.31      0.27      0.29       117
#            1       0.13      0.42      0.20        36
#            2       0.52      0.30      0.38       239
#            3       0.40      0.40      0.40       130
#            4       0.52      0.60      0.56       172
#            5       0.46      0.55      0.50       149
#            6       0.66      0.34      0.45       238
#            7       0.25      0.41      0.31        54
#            8       0.32      0.43      0.37        79
#            9       0.29      0.41      0.34        82
#
#     accuracy                           0.41      1296
#    macro avg       0.39      0.41      0.38      1296
# weighted avg       0.46      0.41      0.41      1296

# %%
path = '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_confusion_matrices'
conf_matrix(path, CStructure_latest)
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_confusion_matrices/13_12_2022-12:30:50_confusion_matrix.npy
# [Text(0.5, 1.0, 'Normalized Chemical Structure Confusion Matrix')]

# %%
# Lists of paths of models that are important with relevant info given time they were created

# %% [markdown]
# # CStructure CP Model Feature Extraction

# %%
if Tomics_latest == True:
    path = '/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_images/loss*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure Loss: ')
    img = display.Image(x)
img

# %%
if Tomics_latest == True:
    path = r'/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_images/acc*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure accuracy: ')
    img = display.Image(x)
img

# %%
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_models')
    print(last_edited_file)
    state = torch.load(last_edited_file)
else:
    x = input('Input path for CStructure Model: ')
    state = torch.load(x)

b = state['valid_loss']
b

# %%
print('Classification Report')
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports')
    print(last_edited_file)
    with open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt', 'r') as f2:
        data = f2.read()
        print(data)
else:
    x = input('Input path for Classification Report: ')
    with open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt', 'r') as f2:
        data = f2.read()
        print(data)
#Chem_Struc_Classification_Report = open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt','r')

# %%
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices')
    print(last_edited_file)
    cf_matrix = np.load(last_edited_file)
else:
    x = input('Input path for confusion matrix: ')
    cf_matrix = np.load(x)
    #cf_matrix = np.load('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices/12_12_2022-13:19:41_confusion_matrix.npy')
cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
'''group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']'''
#group_counts = ['{0:0.0f}'.format(value) for value in
                #cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n' for v1 in group_percentages]
labels = np.asarray(labels).reshape(10, 10)
sns.heatmap(cf_matrix, annot = True, fmt='.2f').set(title = 'Normalized Chemical Structure Confusion Matrix')

# %% [markdown]
# # CStructure CP Model Fine Tuning
