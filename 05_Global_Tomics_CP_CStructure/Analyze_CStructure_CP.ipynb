# %% [markdown]
# ## PREP

# %%
import torch
import glob
from IPython import display
import numpy as np
import seaborn as sns
import os

# %%
# Automatic Loading Based on Latest File Edited
CP_latest = True
CStructur_latest = True
Tomics_latest = True

# %%
def newest(path):
    '''Got from the internet
    Take the latest file added to the directory within a directory and returns the path
    path: path to directory (str)
    '''
    files = os.listdir(path)
    paths = [os.path.join(path, basename) for basename in files]
    return max(paths, key=os.path.getctime)

# %%
def specific_files(path):
    '''Selecting specific models based on the name in the file and then selecting the latest one'''
    files = glob.glob(path)
    paths = [os.path.join(path, basename) for basename in files]
    return max(paths, key=os.path.getctime)

# %% [markdown]
# # CP MODEL

# %%
if CP_latest == True:
    path = '/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/loss*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CP Image Loss: ')
    img = display.Image(x)
img
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/Image_based_model/saved_images/loss_train_val.png

# %%
if CP_latest == True:
    path = r'/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_images/acc*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(last_edited_file)
else:
    x = input('Input path for CP Image Accuracy: ')
    img = display.Image(x)
        
img
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/Image_based_model/saved_images/acc_train_val.png

# %%
if CP_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_models')
    print(last_edited_file)
    state = torch.load(last_edited_file)
else:
    x = input('Input path for CP model: ')
    state = torch.load(x)

b = state['valid_loss']
b
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/Image_based_model/saved_models/CP_least_loss_model
# 8.163949170149863

# %%
print('Classification Report')
if CP_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_classification_reports')
    print(last_edited_file)
    with open(last_edited_file, 'r') as f2:
        data = f2.read()
        print(data)
else:
    x = input('Input path for Classification Report: ')
    with open(x, 'r') as f2:
        data = f2.read()
        print(data)
#Chem_Struc_Classification_Report = open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt','r')
# Out:
# Classification Report
# /home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-17:43:30_classif_report.txt
#               precision    recall  f1-score   support
#
#            0       0.34      0.13      0.19       263
#            1       0.30      0.15      0.20       232
#            2       0.16      0.11      0.13       204
#            3       0.05      0.27      0.08        22
#            4       0.09      0.38      0.14        45
#            5       0.06      0.71      0.10        14
#            6       0.34      0.15      0.21       273
#            7       0.05      0.11      0.07        35
#            8       0.24      0.25      0.24       101
#            9       0.23      0.25      0.24       107
#
#     accuracy                           0.17      1296
#    macro avg       0.18      0.25      0.16      1296
# weighted avg       0.26      0.17      0.19      1296

# %%
if CP_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/02_CP_Models/saved_confusion_matrices')
    print(last_edited_file)
    cf_matrix = np.load(last_edited_file)
else:
    x = input('Input path for confusion matrix: ')
    cf_matrix = np.load(x)
    #cf_matrix = np.load('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices/12_12_2022-13:19:41_confusion_matrix.npy')
cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
'''group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']'''
#group_counts = ['{0:0.0f}'.format(value) for value in
                #cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n' for v1 in group_percentages]
labels = np.asarray(labels).reshape(10, 10)
sns.heatmap(cf_matrix, annot = True, fmt='.2f').set(title = 'Normalized Chemical Structure Confusion Matrix')
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices/12_12_2022-17:43:30_confusion_matrix.npy
# [Text(0.5, 1.0, 'Normalized Chemical Structure Confusion Matrix')]

# %% [markdown]
# # CStructure Model

# %%
if CStructur_latest == True:
    path = '/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/loss*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure Loss: ')
    img = display.Image(x)
img
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/loss_train_val_12_12_2022-17:43:29.png

# %%
if CStructur_latest == True:
    path = r'/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/acc*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure accuracy: ')
    img = display.Image(x)
img
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_images/acc_train_val_12_12_2022-17:43:29.png

# %%
if CStructur_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_models')
    print(last_edited_file)
    state = torch.load(last_edited_file)
else:
    x = input('Input path for CStructure Model: ')
    state = torch.load(x)

b = state['valid_loss']
b
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_models/ChemStruc_Least_Loss_Model
# 1.1121077686548233

# %%
print('Classification Report')
if CStructur_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_classification_reports')
    print(last_edited_file)
    with open(last_edited_file, 'r') as f2:
        data = f2.read()
        print(data)
else:
    x = input('Input path for Classification Report: ')
    with open(x, 'r') as f2:
        data = f2.read()
        print(data)
#Chem_Struc_Classification_Report = open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt','r')
# Out:
# Classification Report
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_classification_reports/12_12_2022-17:43:30_classif_report.txt
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90        90
#            1       0.88      0.98      0.93       101
#            2       0.96      0.73      0.83       182
#            3       0.77      0.97      0.86       104
#            4       0.88      0.96      0.92       182
#            5       0.85      0.99      0.91       153
#            6       0.97      0.80      0.88       151
#            7       0.87      0.93      0.90        82
#            8       0.92      0.73      0.82       132
#            9       0.94      0.92      0.93       119
#
#     accuracy                           0.89      1296
#    macro avg       0.89      0.90      0.89      1296
# weighted avg       0.89      0.89      0.88      1296

# %%
if CStructur_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_confusion_matrices')
    print(last_edited_file)
    cf_matrix = np.load(last_edited_file)
else:
    x = input('Input path for confusion matrix: ')
    cf_matrix = np.load(x)
    #cf_matrix = np.load('/home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_confusion_matrices/12_12_2022-13:19:41_confusion_matrix.npy')
cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
'''group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']'''
#group_counts = ['{0:0.0f}'.format(value) for value in
                #cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n' for v1 in group_percentages]
labels = np.asarray(labels).reshape(10, 10)
sns.heatmap(cf_matrix, annot = True, fmt='.2f').set(title = 'Normalized Chemical Structure Confusion Matrix')
# Out:
# /home/jovyan/Tomics-CP-Chem-MoA/01_CStructure_Models/saved_confusion_matrices/12_12_2022-17:43:30_confusion_matrix.npy
# [Text(0.5, 1.0, 'Normalized Chemical Structure Confusion Matrix')]

# %% [markdown]
# ## Transcriptomics Based Models

# %%
if Tomics_latest == True:
    path = '/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_images/loss*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure Loss: ')
    img = display.Image(x)
img

# %%
if Tomics_latest == True:
    path = r'/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_images/acc*'
    #files = glob.glob(path)
    last_edited_file = specific_files(path)
    #last_edited_file = newest(path)
    print(last_edited_file)
    img = display.Image(filename = str(last_edited_file))
else:
    x = input('Input path for CStructure accuracy: ')
    img = display.Image(x)
img

# %%
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_models')
    print(last_edited_file)
    state = torch.load(last_edited_file)
else:
    x = input('Input path for CStructure Model: ')
    state = torch.load(x)

b = state['valid_loss']
b

# %%
print('Classification Report')
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports')
    print(last_edited_file)
    with open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt', 'r') as f2:
        data = f2.read()
        print(data)
else:
    x = input('Input path for Classification Report: ')
    with open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt', 'r') as f2:
        data = f2.read()
        print(data)
#Chem_Struc_Classification_Report = open('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_classification_reports/12_12_2022-14:23:33_classif_report.txt','r')

# %%
if Tomics_latest == True:
    last_edited_file = newest('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices')
    print(last_edited_file)
    cf_matrix = np.load(last_edited_file)
else:
    x = input('Input path for confusion matrix: ')
    cf_matrix = np.load(x)
    #cf_matrix = np.load('/home/jovyan/Tomics-CP-Chem-MoA/Compound_structure_based_models/saved_confusion_matrices/12_12_2022-13:19:41_confusion_matrix.npy')
cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]
'''group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']'''
#group_counts = ['{0:0.0f}'.format(value) for value in
                #cf_matrix.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f'{v1}\n' for v1 in group_percentages]
labels = np.asarray(labels).reshape(10, 10)
sns.heatmap(cf_matrix, annot = True, fmt='.2f').set(title = 'Normalized Chemical Structure Confusion Matrix')
